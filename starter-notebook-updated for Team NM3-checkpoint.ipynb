# %% [markdown]
# # Regression Predict Student Solution
#
# © Explore Data Science Academy
#
# ---
# ### Honour Code
#
# I {**YOUR NAME, YOUR SURNAME**}, confirm - by submitting this document - that the solutions in this notebook are a result of my own work and that I abide by the [EDSA honour code](https://drive.google.com/file/d/1QDCjGZJ8-FmJE3bZdIQNwnJyQKPhHZBn/view?usp=sharing).
#
# Non-compliance with the honour code constitutes a material breach of contract.
#
# ### Predict Overview: Spain Electricity Shortfall Challenge
#
# The government of Spain is considering an expansion of it's renewable energy resource infrastructure investments. As such, they require information on the trends and patterns of the countries renewable sources and fossil fuel energy generation. Your company has been awarded the contract to:
#
# - 1. analyse the supplied data;
# - 2. identify potential errors in the data and clean the existing data set;
# - 3. determine if additional features can be added to enrich the data set;
# - 4. build a model that is capable of forecasting the three hourly demand shortfalls;
# - 5. evaluate the accuracy of the best machine learning model;
# - 6. determine what features were most important in the model’s prediction decision, and
# - 7. explain the inner working of the model to a non-technical audience.
#
# Formally the problem statement was given to you, the senior data scientist, by your manager via email reads as follow:
#
# > In this project you are tasked to model the shortfall between the energy generated by means of fossil fuels and various renewable sources - for the country of Spain. The daily shortfall, which will be referred to as the target variable, will be modelled as a function of various city-specific weather features such as `pressure`, `wind speed`, `humidity`, etc. As with all data science projects, the provided features are rarely adequate predictors of the target variable. As such, you are required to perform feature engineering to ensure that you will be able to accurately model Spain's three hourly shortfalls.
#
# On top of this, she has provided you with a starter notebook containing vague explanations of what the main outcomes are.

# %% [markdown]
# <a id="cont"></a>
#
# ## Table of Contents
#
# <a href=#one>1. Importing Packages</a>
#
# <a href=#two>2. Loading Data</a>
#
# <a href=#three>3. Exploratory Data Analysis (EDA)</a>
#
# <a href=#four>4. Data Engineering</a>
#
# <a href=#five>5. Modeling</a>
#
# <a href=#six>6. Model Performance</a>
#
# <a href=#seven>7. Model Explanations</a>

# %% [markdown]
#  <a id="one"></a>
# ## 1. Importing Packages
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Importing Packages ⚡ |
# | :--------------------------- |
# | In this section you are required to import, and briefly discuss, the libraries that will be used throughout your analysis and modelling. |
#
# ---

# %%
#Packages for data analysis and manipulation
import numpy as np
import pandas as pd

#Packages for data visualization
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels as sms
from matplotlib import rc
from statsmodels.graphics.correlation import plot_corr

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
import warnings
warnings.filterwarnings('ignore')

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <a id="two"></a>
# ## 2. Loading the Data
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Loading the data ⚡ |
# | :--------------------------- |
# | In this section you are required to load the data from the `df_train` file into a DataFrame. |
#
# ---

# %%
#This loads the train data set:
train = pd.read_csv('df_train.csv') 

#This loads the test data set:
test = pd.read_csv("df_test.csv")

# %%
#To be sure it is properly loaded, let's checkout the overview of the data for trains.
train.head()
# Out:
#    Unnamed: 0                 time  Madrid_wind_speed Valencia_wind_deg  \
# 0           0  2015-01-01 03:00:00           0.666667           level_5
# 1           1  2015-01-01 06:00:00           0.333333          level_10
# 2           2  2015-01-01 09:00:00           1.000000           level_9
# 3           3  2015-01-01 12:00:00           1.000000           level_8
# 4           4  2015-01-01 15:00:00           1.000000           level_7
#
#    Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 0             0.0             0.666667         74.333333        64.000000
# 1             0.0             1.666667         78.333333        64.666667
# 2             0.0             1.000000         71.333333        64.333333
# 3             0.0             1.000000         65.333333        56.333333
# 4             0.0             1.000000         59.000000        57.000000
#
#    Bilbao_clouds_all  Bilbao_wind_speed  ...  Madrid_temp_max  Barcelona_temp  \
# 0                0.0           1.000000  ...       265.938000      281.013000
# 1                0.0           1.000000  ...       266.386667      280.561667
# 2                0.0           1.000000  ...       272.708667      281.583667
# 3                0.0           1.000000  ...       281.895219      283.434104
# 4                2.0           0.333333  ...       280.678437      284.213167
#
#    Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  Bilbao_temp_max  \
# 0       269.338615   269.338615          281.013000       269.338615
# 1       270.376000   270.376000          280.561667       270.376000
# 2       275.027229   275.027229          281.583667       275.027229
# 3       281.135063   281.135063          283.434104       281.135063
# 4       282.252063   282.252063          284.213167       282.252063
#
#    Seville_temp_min Madrid_temp  Madrid_temp_min  load_shortfall_3h
# 0        274.254667  265.938000       265.938000        6715.666667
# 1        274.945000  266.386667       266.386667        4171.666667
# 2        278.792000  272.708667       272.708667        4274.666667
# 3        285.394000  281.895219       281.895219        5075.666667
# 4        285.513719  280.678437       280.678437        6620.666667
#
# [5 rows x 49 columns]

# %% [markdown]
# Observe that the `trains` dataset has `8763 entries (rows) × 49 features (columns)`

# %%
#Let's also check for test.
test.head()
# Out:
#    Unnamed: 0                 time  Madrid_wind_speed Valencia_wind_deg  \
# 0        8763  2018-01-01 00:00:00           5.000000           level_8
# 1        8764  2018-01-01 03:00:00           4.666667           level_8
# 2        8765  2018-01-01 06:00:00           2.333333           level_7
# 3        8766  2018-01-01 09:00:00           2.666667           level_7
# 4        8767  2018-01-01 12:00:00           4.000000           level_7
#
#    Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 0             0.0             5.000000         87.000000        71.333333
# 1             0.0             5.333333         89.000000        78.000000
# 2             0.0             5.000000         89.000000        89.666667
# 3             0.0             5.333333         93.333333        82.666667
# 4             0.0             8.666667         65.333333        64.000000
#
#    Bilbao_clouds_all  Bilbao_wind_speed  ...  Barcelona_temp_max  \
# 0          20.000000           3.000000  ...          287.816667
# 1           0.000000           3.666667  ...          284.816667
# 2           0.000000           2.333333  ...          284.483333
# 3          26.666667           5.666667  ...          284.150000
# 4          26.666667          10.666667  ...          287.483333
#
#    Madrid_temp_max  Barcelona_temp  Bilbao_temp_min  Bilbao_temp  \
# 0       280.816667      287.356667       276.150000   280.380000
# 1       280.483333      284.190000       277.816667   281.010000
# 2       276.483333      283.150000       276.816667   279.196667
# 3       277.150000      283.190000       279.150000   281.740000
# 4       281.150000      286.816667       281.816667   284.116667
#
#    Barcelona_temp_min  Bilbao_temp_max Seville_temp_min  Madrid_temp  \
# 0          286.816667       285.150000       283.150000   279.866667
# 1          283.483333       284.150000       281.150000   279.193333
# 2          281.816667       282.150000       280.483333   276.340000
# 3          282.150000       284.483333       279.150000   275.953333
# 4          286.150000       286.816667       284.483333   280.686667
#
#    Madrid_temp_min
# 0       279.150000
# 1       278.150000
# 2       276.150000
# 3       274.483333
# 4       280.150000
#
# [5 rows x 48 columns]

# %% [markdown]
# Observe that the `test` data has `2920 entries × 48 features`.

# %% [markdown]
# Next thing we wish to do is to concatenate both the Train and Test sets into one, so that we don't have to person the EDA process seperately, which will save us time and memory size.
# We'll merge both datasets into a new dataset called   `merged_data`.

# %%
#To save time, let's merge the two datasets.
merged_data = pd.concat([train, test]) 

#To be sure it is properly merged, let's view the first 5 rows of the merged dataset.
merged_data.head()
# Out:
#    Unnamed: 0                 time  Madrid_wind_speed Valencia_wind_deg  \
# 0           0  2015-01-01 03:00:00           0.666667           level_5
# 1           1  2015-01-01 06:00:00           0.333333          level_10
# 2           2  2015-01-01 09:00:00           1.000000           level_9
# 3           3  2015-01-01 12:00:00           1.000000           level_8
# 4           4  2015-01-01 15:00:00           1.000000           level_7
#
#    Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 0             0.0             0.666667         74.333333        64.000000
# 1             0.0             1.666667         78.333333        64.666667
# 2             0.0             1.000000         71.333333        64.333333
# 3             0.0             1.000000         65.333333        56.333333
# 4             0.0             1.000000         59.000000        57.000000
#
#    Bilbao_clouds_all  Bilbao_wind_speed  ...  Madrid_temp_max  Barcelona_temp  \
# 0                0.0           1.000000  ...       265.938000      281.013000
# 1                0.0           1.000000  ...       266.386667      280.561667
# 2                0.0           1.000000  ...       272.708667      281.583667
# 3                0.0           1.000000  ...       281.895219      283.434104
# 4                2.0           0.333333  ...       280.678437      284.213167
#
#    Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  Bilbao_temp_max  \
# 0       269.338615   269.338615          281.013000       269.338615
# 1       270.376000   270.376000          280.561667       270.376000
# 2       275.027229   275.027229          281.583667       275.027229
# 3       281.135063   281.135063          283.434104       281.135063
# 4       282.252063   282.252063          284.213167       282.252063
#
#    Seville_temp_min Madrid_temp  Madrid_temp_min  load_shortfall_3h
# 0        274.254667  265.938000       265.938000        6715.666667
# 1        274.945000  266.386667       266.386667        4171.666667
# 2        278.792000  272.708667       272.708667        4274.666667
# 3        285.394000  281.895219       281.895219        5075.666667
# 4        285.513719  280.678437       280.678437        6620.666667
#
# [5 rows x 49 columns]

# %% [markdown]
# After merging both sets into the `merged_data`, we discovered that both the `index` column and the `unnamed` column have the same attributes all the way down, so we decided to drop the `unnamed` column, and then name it into a more useable dataframe called `final_data` as seen below.

# %%
#Since the 'unnamed' column is the same with the index, let's drop it.
final_data = merged_data.drop(['Unnamed: 0'], axis = 1)

#Check the first rows of the final data
final_data.head()
# Out:
#                   time  Madrid_wind_speed Valencia_wind_deg  Bilbao_rain_1h  \
# 0  2015-01-01 03:00:00           0.666667           level_5             0.0
# 1  2015-01-01 06:00:00           0.333333          level_10             0.0
# 2  2015-01-01 09:00:00           1.000000           level_9             0.0
# 3  2015-01-01 12:00:00           1.000000           level_8             0.0
# 4  2015-01-01 15:00:00           1.000000           level_7             0.0
#
#    Valencia_wind_speed  Seville_humidity  Madrid_humidity  Bilbao_clouds_all  \
# 0             0.666667         74.333333        64.000000                0.0
# 1             1.666667         78.333333        64.666667                0.0
# 2             1.000000         71.333333        64.333333                0.0
# 3             1.000000         65.333333        56.333333                0.0
# 4             1.000000         59.000000        57.000000                2.0
#
#    Bilbao_wind_speed  Seville_clouds_all  ...  Madrid_temp_max  \
# 0           1.000000                 0.0  ...       265.938000
# 1           1.000000                 0.0  ...       266.386667
# 2           1.000000                 0.0  ...       272.708667
# 3           1.000000                 0.0  ...       281.895219
# 4           0.333333                 0.0  ...       280.678437
#
#    Barcelona_temp  Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  \
# 0      281.013000       269.338615   269.338615          281.013000
# 1      280.561667       270.376000   270.376000          280.561667
# 2      281.583667       275.027229   275.027229          281.583667
# 3      283.434104       281.135063   281.135063          283.434104
# 4      284.213167       282.252063   282.252063          284.213167
#
#    Bilbao_temp_max Seville_temp_min  Madrid_temp  Madrid_temp_min  \
# 0       269.338615       274.254667   265.938000       265.938000
# 1       270.376000       274.945000   266.386667       266.386667
# 2       275.027229       278.792000   272.708667       272.708667
# 3       281.135063       285.394000   281.895219       281.895219
# 4       282.252063       285.513719   280.678437       280.678437
#
#    load_shortfall_3h
# 0        6715.666667
# 1        4171.666667
# 2        4274.666667
# 3        5075.666667
# 4        6620.666667
#
# [5 rows x 48 columns]

# %%
#Let's view the number of rows and columns in the final_data
final_data.shape
# Out:
# (11683, 48)

# %%
#Observe that the last column (which is for testing) in the dataset has null values.
final_data.tail()
# Out:
#                      time  Madrid_wind_speed Valencia_wind_deg  \
# 2915  2018-12-31 09:00:00           0.333333           level_9
# 2916  2018-12-31 12:00:00           0.333333           level_8
# 2917  2018-12-31 15:00:00           1.000000           level_6
# 2918  2018-12-31 18:00:00           1.000000           level_6
# 2919  2018-12-31 21:00:00           1.333333          level_10
#
#       Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 2915             0.0             2.000000         81.666667        49.666667
# 2916             0.0             1.333333         61.000000        28.333333
# 2917             0.0             3.000000         47.000000        26.333333
# 2918             0.0             2.000000         52.666667        56.666667
# 2919             0.0             2.333333         61.666667        69.333333
#
#       Bilbao_clouds_all  Bilbao_wind_speed  Seville_clouds_all  ...  \
# 2915          80.000000           1.333333                 0.0  ...
# 2916          56.666667           1.000000                 0.0  ...
# 2917           0.000000           0.666667                 0.0  ...
# 2918           0.000000           0.666667                 0.0  ...
# 2919           0.000000           1.333333                 0.0  ...
#
#       Madrid_temp_max  Barcelona_temp  Bilbao_temp_min  Bilbao_temp  \
# 2915       281.483333      278.140000       270.816667   273.210000
# 2916       287.816667      286.150000       278.150000   278.443333
# 2917       288.816667      288.820000       284.150000   285.073333
# 2918       285.150000      284.473333       280.150000   281.626667
# 2919       276.816667      281.133333       276.150000   276.450000
#
#       Barcelona_temp_min  Bilbao_temp_max Seville_temp_min  Madrid_temp  \
# 2915          276.483333       276.150000       279.816667   274.910000
# 2916          285.816667       278.816667       287.150000   283.156667
# 2917          288.150000       285.816667       290.816667   287.733333
# 2918          283.150000       282.816667       287.483333   283.813333
# 2919          278.483333       276.816667       283.816667   276.623333
#
#       Madrid_temp_min  load_shortfall_3h
# 2915       271.150000                NaN
# 2916       280.483333                NaN
# 2917       286.483333                NaN
# 2918       282.150000                NaN
# 2919       276.483333                NaN
#
# [5 rows x 48 columns]

# %% [markdown]
# Observe that the tail of the `load_shortfall_3h` column has null values. This is because of the merged test data. And these null values are what we want to predict in this model.

# %% [markdown]
# ## Observing Different Data Types

# %%
#Let's run a check on the datatypes of the final_data
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11683 entries, 0 to 2919
# Data columns (total 48 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   time                  11683 non-null  object
#  1   Madrid_wind_speed     11683 non-null  float64
#  2   Valencia_wind_deg     11683 non-null  object
#  3   Bilbao_rain_1h        11683 non-null  float64
#  4   Valencia_wind_speed   11683 non-null  float64
#  5   Seville_humidity      11683 non-null  float64
#  6   Madrid_humidity       11683 non-null  float64
#  7   Bilbao_clouds_all     11683 non-null  float64
#  8   Bilbao_wind_speed     11683 non-null  float64
#  9   Seville_clouds_all    11683 non-null  float64
#  10  Bilbao_wind_deg       11683 non-null  float64
#  11  Barcelona_wind_speed  11683 non-null  float64
#  12  Barcelona_wind_deg    11683 non-null  float64
#  13  Madrid_clouds_all     11683 non-null  float64
#  14  Seville_wind_speed    11683 non-null  float64
#  15  Barcelona_rain_1h     11683 non-null  float64
#  16  Seville_pressure      11683 non-null  object
#  17  Seville_rain_1h       11683 non-null  float64
#  18  Bilbao_snow_3h        11683 non-null  float64
#  19  Barcelona_pressure    11683 non-null  float64
#  20  Seville_rain_3h       11683 non-null  float64
#  21  Madrid_rain_1h        11683 non-null  float64
#  22  Barcelona_rain_3h     11683 non-null  float64
#  23  Valencia_snow_3h      11683 non-null  float64
#  24  Madrid_weather_id     11683 non-null  float64
#  25  Barcelona_weather_id  11683 non-null  float64
#  26  Bilbao_pressure       11683 non-null  float64
#  27  Seville_weather_id    11683 non-null  float64
#  28  Valencia_pressure     9161 non-null   float64
#  29  Seville_temp_max      11683 non-null  float64
#  30  Madrid_pressure       11683 non-null  float64
#  31  Valencia_temp_max     11683 non-null  float64
#  32  Valencia_temp         11683 non-null  float64
#  33  Bilbao_weather_id     11683 non-null  float64
#  34  Seville_temp          11683 non-null  float64
#  35  Valencia_humidity     11683 non-null  float64
#  36  Valencia_temp_min     11683 non-null  float64
#  37  Barcelona_temp_max    11683 non-null  float64
#  38  Madrid_temp_max       11683 non-null  float64
#  39  Barcelona_temp        11683 non-null  float64
#  40  Bilbao_temp_min       11683 non-null  float64
#  41  Bilbao_temp           11683 non-null  float64
#  42  Barcelona_temp_min    11683 non-null  float64
#  43  Bilbao_temp_max       11683 non-null  float64
#  44  Seville_temp_min      11683 non-null  float64
#  45  Madrid_temp           11683 non-null  float64
#  46  Madrid_temp_min       11683 non-null  float64
#  47  load_shortfall_3h     8763 non-null   float64
# dtypes: float64(45), object(3)
# memory usage: 4.4+ MB

# %% [markdown]
# Observe the datatype of the `time`, `Valencia_wind_deg`, and `Seville_pressure` columns are `object`. These will be dealt with later.

# %% [markdown]
# ## Checking for Null Values

# %%
final_data.isnull().sum() # here we'll check the sum of null values in each feature/column
# Out:
# time                       0
# Madrid_wind_speed          0
# Valencia_wind_deg          0
# Bilbao_rain_1h             0
# Valencia_wind_speed        0
# Seville_humidity           0
# Madrid_humidity            0
# Bilbao_clouds_all          0
# Bilbao_wind_speed          0
# Seville_clouds_all         0
# Bilbao_wind_deg            0
# Barcelona_wind_speed       0
# Barcelona_wind_deg         0
# Madrid_clouds_all          0
# Seville_wind_speed         0
# Barcelona_rain_1h          0
# Seville_pressure           0
# Seville_rain_1h            0
# Bilbao_snow_3h             0
# Barcelona_pressure         0
# Seville_rain_3h            0
# Madrid_rain_1h             0
# Barcelona_rain_3h          0
# Valencia_snow_3h           0
# Madrid_weather_id          0
# Barcelona_weather_id       0
# Bilbao_pressure            0
# Seville_weather_id         0
# Valencia_pressure       2522
# Seville_temp_max           0
# Madrid_pressure            0
# Valencia_temp_max          0
# Valencia_temp              0
# Bilbao_weather_id          0
# Seville_temp               0
# Valencia_humidity          0
# Valencia_temp_min          0
# Barcelona_temp_max         0
# Madrid_temp_max            0
# Barcelona_temp             0
# Bilbao_temp_min            0
# Bilbao_temp                0
# Barcelona_temp_min         0
# Bilbao_temp_max            0
# Seville_temp_min           0
# Madrid_temp                0
# Madrid_temp_min            0
# load_shortfall_3h       2920
# dtype: int64

# %% [markdown]
# Observe that the `Valencia_pressure` and `load_shortfall_3h` columns have thousands of null values.
#
# For that of `load_shortfall_3h`, the total 2920 null values correspond to the number of rows in the test data. So, this is appropriate.
#
# However, for that of `Valencia_pressure`, we need to 'deal' with it.

# %% [markdown]
# <a id="three"></a>
# ## 3. Exploratory Data Analysis (EDA)
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Exploratory data analysis ⚡ |
# | :--------------------------- |
# | In this section, you are required to perform an in-depth analysis of all the variables in the DataFrame. |
#
# ---

# %% [markdown]
# # I. Univariate Analysis: Non-Graphical

# %% [markdown]
# Let's take a look at the statistical details of our data:

# %%
'''
we want to check the descriptive statictics of each feature/column,
i.e; the count of rows, the mean, the standard deviation, the min, max, q1, media, and q3
'''
final_data.describe()
# Out:
#        Madrid_wind_speed  Bilbao_rain_1h  Valencia_wind_speed  \
# count       11683.000000    11683.000000         11683.000000
# mean            2.433750        0.118698             2.692873
# std             1.831762        0.334918             2.321759
# min             0.000000        0.000000             0.000000
# 25%             1.000000        0.000000             1.000000
# 50%             2.000000        0.000000             2.000000
# 75%             3.333333        0.100000             3.666667
# max            13.333333        3.000000            52.000000
#
#        Seville_humidity  Madrid_humidity  Bilbao_clouds_all  \
# count      11683.000000     11683.000000       11683.000000
# mean          63.774687        58.721818          43.440712
# std           22.219380        24.390621          32.046215
# min            8.333333         6.333333           0.000000
# 25%           46.333333        38.000000          12.000000
# 50%           67.000000        59.333333          45.000000
# 75%           83.000000        80.000000          75.000000
# max          100.000000       100.000000         100.000000
#
#        Bilbao_wind_speed  Seville_clouds_all  Bilbao_wind_deg  \
# count       11683.000000        11683.000000     11683.000000
# mean            1.958629           14.155268       159.878855
# std             1.696043           24.541321       101.005654
# min             0.000000            0.000000         0.000000
# 25%             1.000000            0.000000        76.666667
# 50%             1.333333            0.000000       145.666667
# 75%             2.666667           20.000000       233.333333
# max            12.666667           97.333333       360.000000
#
#        Barcelona_wind_speed  ...  Madrid_temp_max  Barcelona_temp  \
# count          11683.000000  ...     11683.000000    11683.000000
# mean               2.782419  ...       289.377372      289.869413
# std                1.758587  ...         9.594562        6.680538
# min                0.000000  ...       264.983333      270.816667
# 25%                1.333333  ...       282.150000      284.816667
# 50%                2.333333  ...       287.843333      289.426667
# 75%                3.666667  ...       296.483333      295.150000
# max               12.666667  ...       314.483333      308.150000
#
#        Bilbao_temp_min   Bilbao_temp  Barcelona_temp_min  Bilbao_temp_max  \
# count     11683.000000  11683.000000        11683.000000     11683.000000
# mean        284.993657    286.447784          288.616766       288.095397
# std           6.730076      6.738466            6.391989         6.898601
# min         264.483333    267.483333          269.483333       269.063000
# 25%         280.122526    281.483448          284.150000       283.150000
# 50%         284.816667    286.193333          288.276333       287.816667
# 75%         289.816667    291.040000          293.483333       292.483333
# max         309.816667    310.710000          306.816667       317.966667
#
#        Seville_temp_min   Madrid_temp  Madrid_temp_min  load_shortfall_3h
# count      11683.000000  11683.000000     11683.000000        8763.000000
# mean         291.263219    288.282055       287.056222       10673.857612
# std            8.136234      9.258559         9.093455        5218.046404
# min          270.150000    264.983333       264.983333       -6618.000000
# 25%          285.483333    281.250000       280.150000        7390.333333
# 50%          290.382000    286.923333       285.816667       11114.666667
# 75%          296.641333    294.993167       293.708917       14498.166667
# max          314.816667    313.133333       310.383333       31904.000000
#
# [8 rows x 45 columns]

# %% [markdown]
# We noticed that the columns are long and some features were not visible, so we decided to do a descriptive statistics for those features that were not visible, to get a clearer summary of each feature in the dataframe.

# %%
'''
Since there are some features/columns that we were not able to see above, we will seperately perform
a descriptive statistics for them, so we can see all there is for each.
'''

print('Descriptive Statistics Of Barcelona_wind_deg:' ,final_data.Barcelona_wind_deg.describe())
print()
print('Descriptive Statistics Of Madrid_clouds_all:',final_data.Madrid_clouds_all.describe())
print()
print('Descriptive Statistics Of Seville_wind_speed:',final_data.Seville_wind_speed.describe())
print()
print('Descriptive Statistics Of Barcelona_rain_1h:' ,final_data.Barcelona_rain_1h.describe())
print()
print('Descriptive Statistics Of Seville_pressure:',final_data.Seville_pressure.describe())
print()
print('Descriptive Statistics Of Seville_rain_1h:',final_data.Seville_rain_1h.describe())
print()
print('Descriptive Statistics Of Bilbao_snow_3h:' ,final_data.Bilbao_snow_3h.describe())
print()
print('Descriptive Statistics Of Barcelona_pressure:',final_data.Barcelona_pressure.describe())
print()
print('Descriptive Statistics Of Seville_rain_3h:',final_data.Seville_rain_3h.describe())
print()
print('Descriptive Statistics Of Madrid_rain_1h:' ,final_data.Madrid_rain_1h.describe())
print()
print('Descriptive Statistics Of Barcelona_rain_3h:',final_data.Barcelona_rain_3h.describe())
print()
print('Descriptive Statistics Of Valencia_snow_3h:',final_data.Valencia_snow_3h.describe())
print()
print('Descriptive Statistics Of Bilbao_pressure:',final_data.Bilbao_pressure.describe())
print()
print('Descriptive Statistics Of Valencia_pressure:',final_data.Valencia_pressure.describe())
print()
print('Descriptive Statistics Of Seville_temp_max:',final_data.Seville_temp_max.describe())
print()
print('Descriptive Statistics Of Madrid_pressure:' ,final_data.Madrid_pressure.describe())
print()
print('Descriptive Statistics Of Valencia_temp_max:',final_data.Valencia_temp_max.describe())
print()
print('Descriptive Statistics Of Valencia_temp:',final_data.Valencia_temp.describe())
print()
print('Descriptive Statistics Of Bilbao_weather_id:' ,final_data.Bilbao_weather_id.describe())
print()
print('Descriptive Statistics Of Seville_temp:',final_data.Seville_temp.describe())
print()
print('Descriptive Statistics Of Valencia_humidity:',final_data.Valencia_humidity.describe())
print()
print('Descriptive Statistics Of Valencia_temp_min:' ,final_data.Valencia_temp_min.describe())
print()
print('Descriptive Statistics Of Barcelona_temp_max:',final_data.Barcelona_temp_max.describe())
# Out:
# Descriptive Statistics Of Barcelona_wind_deg: count    11683.000000
# mean       187.654241
# std         88.694717
# min          0.000000
# 25%        116.666667
# 50%        193.333333
# 75%        260.000000
# max        360.000000
# Name: Barcelona_wind_deg, dtype: float64
#
# Descriptive Statistics Of Madrid_clouds_all: count    11683.000000
# mean        20.668692
# std         28.478087
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         38.333333
# max        100.000000
# Name: Madrid_clouds_all, dtype: float64
#
# Descriptive Statistics Of Seville_wind_speed: count    11683.000000
# mean         2.483067
# std          1.705508
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.333333
# max         12.666667
# Name: Seville_wind_speed, dtype: float64
#
# Descriptive Statistics Of Barcelona_rain_1h: count    11683.000000
# mean         0.108534
# std          0.556794
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         12.000000
# Name: Barcelona_rain_1h, dtype: float64
#
# Descriptive Statistics Of Seville_pressure: count     11683
# unique       25
# top        sp10
# freq        673
# Name: Seville_pressure, dtype: object
#
# Descriptive Statistics Of Seville_rain_1h: count    11683.000000
# mean         0.041120
# std          0.180425
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          3.000000
# Name: Seville_rain_1h, dtype: float64
#
# Descriptive Statistics Of Bilbao_snow_3h: count    11683.000000
# mean         0.023936
# std          0.482817
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         21.300000
# Name: Bilbao_snow_3h, dtype: float64
#
# Descriptive Statistics Of Barcelona_pressure: count    1.168300e+04
# mean     1.287326e+03
# std      1.218906e+04
# min      6.706667e+02
# 25%      1.013667e+03
# 50%      1.017333e+03
# 75%      1.021167e+03
# max      1.001411e+06
# Name: Barcelona_pressure, dtype: float64
#
# Descriptive Statistics Of Seville_rain_3h: count    11683.000000
# mean         0.000182
# std          0.003171
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.093333
# Name: Seville_rain_3h, dtype: float64
#
# Descriptive Statistics Of Madrid_rain_1h: count    11683.000000
# mean         0.043328
# std          0.163996
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          3.000000
# Name: Madrid_rain_1h, dtype: float64
#
# Descriptive Statistics Of Barcelona_rain_3h: count    11683.000000
# mean         0.000331
# std          0.003466
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.093000
# Name: Barcelona_rain_3h, dtype: float64
#
# Descriptive Statistics Of Valencia_snow_3h: count    11683.000000
# mean         0.000154
# std          0.010277
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.791667
# Name: Valencia_snow_3h, dtype: float64
#
# Descriptive Statistics Of Bilbao_pressure: count    11683.000000
# mean      1017.482011
# std          9.753552
# min        971.333333
# 25%       1013.333333
# 50%       1018.666667
# 75%       1023.333333
# max       1042.000000
# Name: Bilbao_pressure, dtype: float64
#
# Descriptive Statistics Of Valencia_pressure: count    9161.000000
# mean     1012.346687
# std         8.817473
# min       972.666667
# 25%      1010.666667
# 50%      1015.000000
# 75%      1018.000000
# max      1021.666667
# Name: Valencia_pressure, dtype: float64
#
# Descriptive Statistics Of Seville_temp_max: count    11683.000000
# mean       296.007363
# std          8.929160
# min        272.063000
# 25%        289.483333
# 50%        295.483333
# 75%        302.816667
# max        320.483333
# Name: Seville_temp_max, dtype: float64
#
# Descriptive Statistics Of Madrid_pressure: count    11683.000000
# mean      1011.797412
# std         19.983122
# min        927.666667
# 25%       1012.666667
# 50%       1017.333333
# 75%       1021.666667
# max       1038.000000
# Name: Madrid_pressure, dtype: float64
#
# Descriptive Statistics Of Valencia_temp_max: count    11683.000000
# mean       291.362722
# std          7.441278
# min        269.888000
# 25%        285.783333
# 50%        291.150000
# 75%        297.159167
# max        314.263333
# Name: Valencia_temp_max, dtype: float64
#
# Descriptive Statistics Of Valencia_temp: count    11683.000000
# mean       290.788513
# std          7.157835
# min        269.888000
# 25%        285.395500
# 50%        290.483333
# 75%        296.437500
# max        310.426667
# Name: Valencia_temp, dtype: float64
#
# Descriptive Statistics Of Bilbao_weather_id: count    11683.000000
# mean       727.800750
# std        113.616789
# min        207.333333
# 25%        701.000000
# 50%        800.000000
# 75%        801.666667
# max        804.000000
# Name: Bilbao_weather_id, dtype: float64
#
# Descriptive Statistics Of Seville_temp: count    11683.000000
# mean       293.170948
# std          7.998774
# min        272.063000
# 25%        287.403167
# 50%        292.470000
# 75%        298.806667
# max        314.976667
# Name: Seville_temp, dtype: float64
#
# Descriptive Statistics Of Valencia_humidity: count    11683.000000
# mean        65.091814
# std         19.040927
# min         10.333333
# 25%         51.333333
# 50%         66.333333
# 75%         80.666667
# max        100.000000
# Name: Valencia_humidity, dtype: float64
#
# Descriptive Statistics Of Valencia_temp_min: count    11683.000000
# mean       290.229939
# std          7.003619
# min        269.888000
# 25%        284.928833
# 50%        289.820000
# 75%        295.491667
# max        310.272000
# Name: Valencia_temp_min, dtype: float64
#
# Descriptive Statistics Of Barcelona_temp_max: count    11683.000000
# mean       291.042128
# std          7.236360
# min        272.150000
# 25%        285.338609
# 50%        290.150000
# 75%        296.816667
# max        314.076667
# Name: Barcelona_temp_max, dtype: float64

# %% [markdown]
# ### Skew Analysis

# %% [markdown]
# Next we want to perform a `Skew Analysis` for each variable in the dataframe to find out how skewed they are

# %%
'''
We will peform a skew analysis to know symetricall the variables are
'''
print('Skew Analysis For Each Feature In The Dataframe')
final_data.skew()
# Out:
# Skew Analysis For Each Feature In The Dataframe
# Madrid_wind_speed        1.452792
# Bilbao_rain_1h           5.694539
# Valencia_wind_speed      3.116352
# Seville_humidity        -0.366033
# Madrid_humidity         -0.076590
# Bilbao_clouds_all       -0.068335
# Bilbao_wind_speed        1.602522
# Seville_clouds_all       1.765104
# Bilbao_wind_deg          0.246848
# Barcelona_wind_speed     1.072417
# Barcelona_wind_deg      -0.140337
# Madrid_clouds_all        1.158486
# Seville_wind_speed       1.213437
# Barcelona_rain_1h        9.833191
# Seville_rain_1h          7.535944
# Bilbao_snow_3h          30.237039
# Barcelona_pressure      66.949053
# Seville_rain_3h         22.349167
# Madrid_rain_1h           6.446514
# Barcelona_rain_3h       14.668923
# Valencia_snow_3h        73.090853
# Madrid_weather_id       -2.909054
# Barcelona_weather_id    -2.595417
# Bilbao_pressure         -0.977531
# Seville_weather_id      -3.230498
# Valencia_pressure       -1.800572
# Seville_temp_max         0.122162
# Madrid_pressure         -2.140249
# Valencia_temp_max        0.068277
# Valencia_temp            0.045860
# Bilbao_weather_id       -1.317090
# Seville_temp             0.219842
# Valencia_humidity       -0.292647
# Valencia_temp_min        0.069526
# Barcelona_temp_max       0.241542
# Madrid_temp_max          0.321176
# Barcelona_temp           0.105580
# Bilbao_temp_min          0.202540
# Bilbao_temp              0.270550
# Barcelona_temp_min       0.002288
# Bilbao_temp_max          0.331307
# Seville_temp_min         0.305592
# Madrid_temp              0.325114
# Madrid_temp_min          0.296405
# load_shortfall_3h       -0.384847
# dtype: float64

# %% [markdown]
# |   Skew Value (x)  |       Description of Data      |
# |:-------------------|:---------------:|
# | -0.5 < x < 0.5              |Fairly Symmetrical |
# | -1 < x < -0.5 | Moderate Negative Skew  |
# | 0.5 < x < 1             | Moderate Positive Skew  |
# |       x < -1     |High Negative Skew  |
# |       x > 1  |High Positve Skew |
#
# <div align="left" style="width: 500px; font-size: 80%; text-align: left; margin: 0 auto">
# <img src="https://github.com/Explore-AI/Pictures/blob/f3aeedd2c056ddd233301c7186063618c1041140/regression_analysis_notebook/skew.jpg?raw=True"
#      alt="Dummy image 1"
#      style="float: left; padding-bottom=0.5em"
#      width=500px/>

# %% [markdown]
# '''
# Fairly Symetrical: `22 Features`
# Highly Negatively Skewed: `7 Features`
# Highly Positively Skewed: `16 Features`
# Moderate Negatively Skewed: `1 Feature(s)`
# Moderate Positively Skewed: `0 Features`
#
# '''

# %% [markdown]
# ### Kurtosis Analysis

# %% [markdown]
# We then also perform a kurtosis analysis for each variable to
# describe the distribution of observed data around the mean.

# %%
print('Kurtosis Analysis For Each Feature In The Dataframe')
final_data.kurtosis()
# Out:
# Kurtosis Analysis For Each Feature In The Dataframe
# Madrid_wind_speed          2.156333
# Bilbao_rain_1h            40.584429
# Valencia_wind_speed       31.014311
# Seville_humidity          -0.950169
# Madrid_humidity           -1.151940
# Bilbao_clouds_all         -1.519626
# Bilbao_wind_speed          3.159652
# Seville_clouds_all         1.950894
# Bilbao_wind_deg           -1.064464
# Barcelona_wind_speed       1.519692
# Barcelona_wind_deg        -0.967252
# Madrid_clouds_all         -0.076188
# Seville_wind_speed         1.745508
# Barcelona_rain_1h        130.956428
# Seville_rain_1h           79.440881
# Bilbao_snow_3h          1075.823322
# Barcelona_pressure      4916.988101
# Seville_rain_3h          552.067395
# Madrid_rain_1h            63.372354
# Barcelona_rain_3h        251.188884
# Valencia_snow_3h        5452.830025
# Madrid_weather_id          8.018543
# Barcelona_weather_id       5.932283
# Bilbao_pressure            1.847650
# Seville_weather_id        10.402060
# Valencia_pressure          2.939921
# Seville_temp_max          -0.596016
# Madrid_pressure            3.733443
# Valencia_temp_max         -0.653975
# Valencia_temp             -0.697508
# Bilbao_weather_id          0.372580
# Seville_temp              -0.495430
# Valencia_humidity         -0.723163
# Valencia_temp_min         -0.670813
# Barcelona_temp_max        -0.745647
# Madrid_temp_max           -0.668313
# Barcelona_temp            -0.741932
# Bilbao_temp_min           -0.291655
# Bilbao_temp               -0.151370
# Barcelona_temp_min        -0.571935
# Bilbao_temp_max            0.199065
# Seville_temp_min          -0.428714
# Madrid_temp               -0.634603
# Madrid_temp_min           -0.683538
# load_shortfall_3h         -0.118999
# dtype: float64

# %% [markdown]
# # II. Univariate Analysis:  Graphical

# %% [markdown]
# ### a. Histogram and Density Plot
# For the Histogram and Density Plot, we will use both matplotlib and seaborn and plot for all the numerical features. We can visualise all numerical features simultaneously as shown below.

# %%
'''
Here, rather than plotting the Histogram and Density plots seperately, we merge them together to save time
and lso memory space, since the Density plot is the curve around the distribution of the Histogram over a period of time
'''
plt.figure(figsize=(20,10))
sns.distplot(a=final_data.Barcelona_wind_deg, color='blue',
             hist_kws={"edgecolor": 'black'})
plt.show()

plt.figure(figsize=(20,10))
sns.distplot(a=final_data.Seville_humidity, color='green',
             hist_kws={"edgecolor": 'black'})
plt.show()

plt.figure(figsize=(20,10))
sns.distplot(a=final_data.Bilbao_clouds_all, color='red',
             hist_kws={"edgecolor": 'black'})
plt.show()

plt.figure(figsize=(20,10))
sns.distplot(a=final_data.Seville_temp_max, color='yellow',
             hist_kws={"edgecolor": 'black'})
plt.show()

plt.figure(figsize=(20,10))
sns.distplot(a=final_data.Madrid_temp_min, color='blue',
             hist_kws={"edgecolor": 'black'})
plt.show()

plt.figure(figsize=(20,10))
sns.distplot(a=final_data.Bilbao_temp_max, color='red',
             hist_kws={"edgecolor": 'black'})
plt.show()

plt.figure(figsize=(20,10))
sns.distplot(a=final_data.Madrid_pressure, color='blue',
             hist_kws={"edgecolor": 'black'})
plt.show()

# %% [markdown]
# From the selected histogram and density plots above, we are able to see a summary of the continuos datas in the datasets and also how distributed they are over a continous interval or time period, also we can see that the input variables will have an effect on our target variable in the model building and deploment phase.

# %% [markdown]
# ### b. Box Plot and Violin Plot
# For the Box Plot and Violin Plot, we will use the seaborn library and only select three random features instead of all the numerical features. We can visualise all numerical features simultaneously,
# but as the range of values for each feature is different, it will not create a useful visualisation.

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='Madrid_wind_speed', data=final_data);

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='Bilbao_rain_1h', data=final_data);

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='Valencia_wind_speed', data=final_data);

# %%
plt.figure(figsize=(12,5))
sns.violinplot(x='Madrid_wind_speed', data=final_data);

# %%
plt.figure(figsize=(12,5))
sns.violinplot(x='Bilbao_rain_1h', data=final_data);

# %%
plt.figure(figsize=(12,5))
sns.violinplot(x='Valencia_wind_speed', data=final_data);

# %% [markdown]
# From the `Box Plot` above, we are able to depict how spread out the data is and also able to see the outliers in each feature.
#
# The `Violin Plot`

# %% [markdown]
#  # III.  Multivariate Analysis: Non-Graphical

# %%
final_data.corr()
# Out:
#                       Madrid_wind_speed  Bilbao_rain_1h  Valencia_wind_speed  \
# Madrid_wind_speed              1.000000        0.247761             0.524549
# Bilbao_rain_1h                 0.247761        1.000000             0.240118
# Valencia_wind_speed            0.524549        0.240118             1.000000
# Seville_humidity              -0.114347        0.063048            -0.095533
# Madrid_humidity               -0.116172        0.098192            -0.029066
# Bilbao_clouds_all              0.225566        0.361385             0.192272
# Bilbao_wind_speed              0.382617        0.075120             0.398683
# Seville_clouds_all             0.185177        0.074137             0.146475
# Bilbao_wind_deg                0.272466        0.255858             0.255511
# Barcelona_wind_speed           0.272295        0.070787             0.350592
# Barcelona_wind_deg            -0.083599       -0.020902            -0.057883
# Madrid_clouds_all              0.245055        0.127963             0.229440
# Seville_wind_speed             0.429858        0.118810             0.309374
# Barcelona_rain_1h              0.062114        0.060390             0.027630
# Seville_rain_1h                0.112461        0.083222             0.048719
# Bilbao_snow_3h                 0.062032        0.096260             0.101233
# Barcelona_pressure             0.009569        0.051968             0.044150
# Seville_rain_3h                0.004014        0.018764             0.022129
# Madrid_rain_1h                 0.170672        0.157344             0.100311
# Barcelona_rain_3h             -0.013045        0.003576            -0.038103
# Valencia_snow_3h               0.018883        0.008780             0.052041
# Madrid_weather_id             -0.178500       -0.126045            -0.103358
# Barcelona_weather_id          -0.094986       -0.110104            -0.041051
# Bilbao_pressure               -0.278214       -0.064473            -0.128770
# Seville_weather_id            -0.119056       -0.088641            -0.065004
# Valencia_pressure             -0.203967       -0.214059            -0.074355
# Seville_temp_max               0.027694       -0.173351            -0.037404
# Madrid_pressure               -0.153231       -0.302455            -0.143971
# Valencia_temp_max              0.109921       -0.137050             0.067461
# Valencia_temp                  0.106533       -0.133444             0.076280
# Bilbao_weather_id             -0.228350       -0.603190            -0.177013
# Seville_temp                   0.059882       -0.152139            -0.014881
# Valencia_humidity             -0.293759       -0.090703            -0.429268
# Valencia_temp_min              0.100117       -0.126690             0.082254
# Barcelona_temp_max             0.038752       -0.153656            -0.035119
# Madrid_temp_max                0.064625       -0.148284            -0.020645
# Barcelona_temp                 0.051990       -0.138938            -0.016290
# Bilbao_temp_min                0.051152       -0.143191            -0.002094
# Bilbao_temp                    0.036799       -0.182022            -0.014087
# Barcelona_temp_min             0.059285       -0.114654             0.005129
# Bilbao_temp_max                0.020677       -0.219710            -0.024867
# Seville_temp_min               0.077828       -0.120818             0.002894
# Madrid_temp                    0.078077       -0.137182            -0.012830
# Madrid_temp_min                0.064200       -0.120395            -0.024767
# load_shortfall_3h             -0.150981       -0.152510            -0.142791
#
#                       Seville_humidity  Madrid_humidity  Bilbao_clouds_all  \
# Madrid_wind_speed            -0.114347        -0.116172           0.225566
# Bilbao_rain_1h                0.063048         0.098192           0.361385
# Valencia_wind_speed          -0.095533        -0.029066           0.192272
# Seville_humidity              1.000000         0.794435           0.055132
# Madrid_humidity               0.794435         1.000000           0.033094
# Bilbao_clouds_all             0.055132         0.033094           1.000000
# Bilbao_wind_speed            -0.096654        -0.012729           0.024394
# Seville_clouds_all            0.397249         0.363340           0.037675
# Bilbao_wind_deg              -0.118299        -0.091650           0.267920
# Barcelona_wind_speed         -0.154620        -0.065749           0.081249
# Barcelona_wind_deg            0.169172         0.187128          -0.056930
# Madrid_clouds_all             0.347442         0.498062           0.090741
# Seville_wind_speed           -0.205987        -0.121950           0.062569
# Barcelona_rain_1h            -0.045171        -0.049671           0.053865
# Seville_rain_1h               0.229563         0.196892           0.030161
# Bilbao_snow_3h                0.018271         0.024683           0.070549
# Barcelona_pressure            0.017912         0.020566           0.032980
# Seville_rain_3h               0.027446         0.048725           0.008520
# Madrid_rain_1h                0.148648         0.246944           0.079419
# Barcelona_rain_3h             0.008624         0.009986          -0.035891
# Valencia_snow_3h              0.005728         0.010059           0.021423
# Madrid_weather_id            -0.216339        -0.346911          -0.073259
# Barcelona_weather_id         -0.054883        -0.067316          -0.120654
# Bilbao_pressure              -0.119706        -0.098388           0.002846
# Seville_weather_id           -0.327958        -0.286516          -0.029508
# Valencia_pressure            -0.093324        -0.170549          -0.097868
# Seville_temp_max             -0.602483        -0.610552          -0.103973
# Madrid_pressure              -0.086149        -0.100597          -0.131503
# Valencia_temp_max            -0.641650        -0.702760          -0.011646
# Valencia_temp                -0.646328        -0.699706          -0.013887
# Bilbao_weather_id            -0.107606        -0.140293          -0.526723
# Seville_temp                 -0.745160        -0.741594          -0.102323
# Valencia_humidity             0.459938         0.383107          -0.119219
# Valencia_temp_min            -0.635370        -0.681341          -0.016264
# Barcelona_temp_max           -0.602008        -0.686650          -0.043627
# Madrid_temp_max              -0.699489        -0.798668          -0.060564
# Barcelona_temp               -0.605897        -0.677792          -0.035391
# Bilbao_temp_min              -0.593035        -0.626489          -0.082353
# Bilbao_temp                  -0.589058        -0.620312          -0.126287
# Barcelona_temp_min           -0.581922        -0.636039          -0.025979
# Bilbao_temp_max              -0.563753        -0.590620          -0.170196
# Seville_temp_min             -0.776715        -0.764148          -0.089831
# Madrid_temp                  -0.703010        -0.795066          -0.059928
# Madrid_temp_min              -0.675070        -0.757692          -0.060271
# load_shortfall_3h            -0.167290        -0.150536          -0.127293
#
#                       Bilbao_wind_speed  Seville_clouds_all  Bilbao_wind_deg  \
# Madrid_wind_speed              0.382617            0.185177         0.272466
# Bilbao_rain_1h                 0.075120            0.074137         0.255858
# Valencia_wind_speed            0.398683            0.146475         0.255511
# Seville_humidity              -0.096654            0.397249        -0.118299
# Madrid_humidity               -0.012729            0.363340        -0.091650
# Bilbao_clouds_all              0.024394            0.037675         0.267920
# Bilbao_wind_speed              1.000000            0.132678         0.440740
# Seville_clouds_all             0.132678            1.000000         0.042427
# Bilbao_wind_deg                0.440740            0.042427         1.000000
# Barcelona_wind_speed           0.268904            0.111393         0.176470
# Barcelona_wind_deg            -0.018832           -0.024593        -0.027336
# Madrid_clouds_all              0.240763            0.519606         0.074971
# Seville_wind_speed             0.234165            0.148204         0.130353
# Barcelona_rain_1h             -0.030182            0.003392         0.020294
# Seville_rain_1h                0.081858            0.417028         0.028629
# Bilbao_snow_3h                -0.004587            0.000581        -0.036590
# Barcelona_pressure             0.006825            0.016911         0.029709
# Seville_rain_3h               -0.026257            0.073736         0.005330
# Madrid_rain_1h                 0.113866            0.296438         0.055614
# Barcelona_rain_3h             -0.038457            0.023018         0.006023
# Valencia_snow_3h              -0.007983           -0.008648        -0.019983
# Madrid_weather_id             -0.116663           -0.366878        -0.039853
# Barcelona_weather_id          -0.009093           -0.080385        -0.044712
# Bilbao_pressure               -0.161059           -0.349051        -0.107914
# Seville_weather_id            -0.081810           -0.538608        -0.006960
# Valencia_pressure              0.013334           -0.219947        -0.124272
# Seville_temp_max               0.057233           -0.184094        -0.032880
# Madrid_pressure                0.060654           -0.214577        -0.153101
# Valencia_temp_max              0.074952           -0.180236         0.086974
# Valencia_temp                  0.080772           -0.176475         0.088317
# Bilbao_weather_id             -0.029676           -0.091527        -0.241632
# Seville_temp                   0.054443           -0.203062         0.034798
# Valencia_humidity             -0.288651            0.085376        -0.242935
# Valencia_temp_min              0.084195           -0.167976         0.089941
# Barcelona_temp_max            -0.000745           -0.195812         0.064333
# Madrid_temp_max                0.015822           -0.231967         0.051832
# Barcelona_temp                 0.008407           -0.178549         0.080329
# Bilbao_temp_min                0.098830           -0.132287         0.110097
# Bilbao_temp                    0.131612           -0.144719         0.084298
# Barcelona_temp_min             0.016688           -0.150584         0.094344
# Bilbao_temp_max                0.166347           -0.152165         0.052073
# Seville_temp_min               0.047191           -0.194561         0.080600
# Madrid_temp                    0.019764           -0.222425         0.063938
# Madrid_temp_min                0.006009           -0.213539         0.062808
# load_shortfall_3h             -0.081602           -0.091804        -0.120800
#
#                       Barcelona_wind_speed  ...  Madrid_temp_max  \
# Madrid_wind_speed                 0.272295  ...         0.064625
# Bilbao_rain_1h                    0.070787  ...        -0.148284
# Valencia_wind_speed               0.350592  ...        -0.020645
# Seville_humidity                 -0.154620  ...        -0.699489
# Madrid_humidity                  -0.065749  ...        -0.798668
# Bilbao_clouds_all                 0.081249  ...        -0.060564
# Bilbao_wind_speed                 0.268904  ...         0.015822
# Seville_clouds_all                0.111393  ...        -0.231967
# Bilbao_wind_deg                   0.176470  ...         0.051832
# Barcelona_wind_speed              1.000000  ...         0.071381
# Barcelona_wind_deg                0.115323  ...        -0.207219
# Madrid_clouds_all                 0.137969  ...        -0.294171
# Seville_wind_speed                0.198329  ...         0.105318
# Barcelona_rain_1h                 0.043223  ...         0.062193
# Seville_rain_1h                   0.087841  ...        -0.132165
# Bilbao_snow_3h                    0.016380  ...        -0.073427
# Barcelona_pressure                0.002241  ...        -0.013671
# Seville_rain_3h                   0.054507  ...        -0.041878
# Madrid_rain_1h                    0.107048  ...        -0.112748
# Barcelona_rain_3h                 0.003317  ...        -0.039264
# Valencia_snow_3h                  0.027525  ...        -0.021520
# Madrid_weather_id                -0.090894  ...         0.153196
# Barcelona_weather_id             -0.029625  ...         0.045221
# Bilbao_pressure                  -0.071494  ...        -0.077532
# Seville_weather_id               -0.074467  ...         0.196139
# Valencia_pressure                -0.106413  ...         0.147867
# Seville_temp_max                  0.154098  ...         0.781381
# Madrid_pressure                  -0.032934  ...         0.082555
# Valencia_temp_max                 0.113982  ...         0.920765
# Valencia_temp                     0.094255  ...         0.918433
# Bilbao_weather_id                -0.054319  ...         0.169984
# Seville_temp                      0.142386  ...         0.915537
# Valencia_humidity                -0.243724  ...        -0.245955
# Valencia_temp_min                 0.069783  ...         0.895486
# Barcelona_temp_max                0.099210  ...         0.911618
# Madrid_temp_max                   0.071381  ...         1.000000
# Barcelona_temp                    0.095109  ...         0.905429
# Bilbao_temp_min                   0.110704  ...         0.871614
# Bilbao_temp                       0.106629  ...         0.874711
# Barcelona_temp_min                0.083827  ...         0.853428
# Bilbao_temp_max                   0.094279  ...         0.846612
# Seville_temp_min                  0.122419  ...         0.925381
# Madrid_temp                       0.072738  ...         0.990703
# Madrid_temp_min                   0.063878  ...         0.950082
# load_shortfall_3h                -0.103633  ...         0.182548
#
#                       Barcelona_temp  Bilbao_temp_min  Bilbao_temp  \
# Madrid_wind_speed           0.051990         0.051152     0.036799
# Bilbao_rain_1h             -0.138938        -0.143191    -0.182022
# Valencia_wind_speed        -0.016290        -0.002094    -0.014087
# Seville_humidity           -0.605897        -0.593035    -0.589058
# Madrid_humidity            -0.677792        -0.626489    -0.620312
# Bilbao_clouds_all          -0.035391        -0.082353    -0.126287
# Bilbao_wind_speed           0.008407         0.098830     0.131612
# Seville_clouds_all         -0.178549        -0.132287    -0.144719
# Bilbao_wind_deg             0.080329         0.110097     0.084298
# Barcelona_wind_speed        0.095109         0.110704     0.106629
# Barcelona_wind_deg         -0.208203        -0.190814    -0.175033
# Madrid_clouds_all          -0.235327        -0.176138    -0.177553
# Seville_wind_speed          0.086789         0.092657     0.085078
# Barcelona_rain_1h           0.040397         0.017288     0.019557
# Seville_rain_1h            -0.110684        -0.083090    -0.088617
# Bilbao_snow_3h             -0.073329        -0.074100    -0.084697
# Barcelona_pressure         -0.028144        -0.019325    -0.024080
# Seville_rain_3h            -0.035338        -0.018074    -0.028728
# Madrid_rain_1h             -0.056557        -0.042620    -0.052561
# Barcelona_rain_3h          -0.036066        -0.022611    -0.037840
# Valencia_snow_3h           -0.024687        -0.024653    -0.027858
# Madrid_weather_id           0.091573         0.061450     0.069606
# Barcelona_weather_id        0.049620         0.072850     0.073393
# Bilbao_pressure            -0.149296        -0.195695    -0.186387
# Seville_weather_id          0.176714         0.137725     0.139720
# Valencia_pressure           0.070433         0.052484     0.113191
# Seville_temp_max            0.703882         0.667463     0.700773
# Madrid_pressure             0.016599         0.015817     0.089857
# Valencia_temp_max           0.920304         0.850950     0.860375
# Valencia_temp               0.923282         0.855774     0.859733
# Bilbao_weather_id           0.149682         0.162106     0.205700
# Seville_temp                0.846929         0.814716     0.826537
# Valencia_humidity          -0.233254        -0.252637    -0.241863
# Valencia_temp_min           0.905283         0.841950     0.839833
# Barcelona_temp_max          0.978799         0.865840     0.873706
# Madrid_temp_max             0.905429         0.871614     0.874711
# Barcelona_temp              1.000000         0.875896     0.872009
# Bilbao_temp_min             0.875896         1.000000     0.984934
# Bilbao_temp                 0.872009         0.984934     1.000000
# Barcelona_temp_min          0.972538         0.846380     0.828164
# Bilbao_temp_max             0.836994         0.936350     0.981878
# Seville_temp_min            0.871794         0.844842     0.839745
# Madrid_temp                 0.908504         0.880266     0.877367
# Madrid_temp_min             0.880456         0.854735     0.846663
# load_shortfall_3h           0.182673         0.172920     0.176411
#
#                       Barcelona_temp_min  Bilbao_temp_max  Seville_temp_min  \
# Madrid_wind_speed               0.059285         0.020677          0.077828
# Bilbao_rain_1h                 -0.114654        -0.219710         -0.120818
# Valencia_wind_speed             0.005129        -0.024867          0.002894
# Seville_humidity               -0.581922        -0.563753         -0.776715
# Madrid_humidity                -0.636039        -0.590620         -0.764148
# Bilbao_clouds_all              -0.025979        -0.170196         -0.089831
# Bilbao_wind_speed               0.016688         0.166347          0.047191
# Seville_clouds_all             -0.150584        -0.152165         -0.194561
# Bilbao_wind_deg                 0.094344         0.052073          0.080600
# Barcelona_wind_speed            0.083827         0.094279          0.122419
# Barcelona_wind_deg             -0.240982        -0.157998         -0.202260
# Madrid_clouds_all              -0.203858        -0.169963         -0.254942
# Seville_wind_speed              0.099924         0.075710          0.156655
# Barcelona_rain_1h               0.006781         0.016467          0.052684
# Seville_rain_1h                -0.094789        -0.090638         -0.113496
# Bilbao_snow_3h                 -0.066923        -0.094561         -0.063481
# Barcelona_pressure             -0.025059        -0.028809         -0.027596
# Seville_rain_3h                -0.025793        -0.039687         -0.026085
# Madrid_rain_1h                 -0.034034        -0.059967         -0.077292
# Barcelona_rain_3h              -0.026261        -0.054115         -0.005718
# Valencia_snow_3h               -0.022863        -0.030792         -0.016472
# Madrid_weather_id               0.065862         0.073374          0.114223
# Barcelona_weather_id            0.058264         0.073701          0.037188
# Bilbao_pressure                -0.150230        -0.169075         -0.089648
# Seville_weather_id              0.161468         0.135876          0.178897
# Valencia_pressure               0.002960         0.174744          0.063142
# Seville_temp_max                0.613980         0.704960          0.783148
# Madrid_pressure                -0.042461         0.169697          0.026266
# Valencia_temp_max               0.867774         0.840263          0.884222
# Valencia_temp                   0.893376         0.836398          0.883368
# Bilbao_weather_id               0.129191         0.246245          0.166713
# Seville_temp                    0.784116         0.806788          0.961565
# Valencia_humidity              -0.245793        -0.222014         -0.279635
# Valencia_temp_min               0.898245         0.813270          0.862583
# Barcelona_temp_max              0.908641         0.848136          0.866634
# Madrid_temp_max                 0.853428         0.846612          0.925381
# Barcelona_temp                  0.972538         0.836994          0.871794
# Bilbao_temp_min                 0.846380         0.936350          0.844842
# Bilbao_temp                     0.828164         0.981878          0.839745
# Barcelona_temp_min              1.000000         0.783587          0.834729
# Bilbao_temp_max                 0.783587         1.000000          0.804049
# Seville_temp_min                0.834729         0.804049          1.000000
# Madrid_temp                     0.867627         0.844112          0.937541
# Madrid_temp_min                 0.854083         0.809808          0.911220
# load_shortfall_3h               0.195984         0.180934          0.174718
#
#                       Madrid_temp  Madrid_temp_min  load_shortfall_3h
# Madrid_wind_speed        0.078077         0.064200          -0.150981
# Bilbao_rain_1h          -0.137182        -0.120395          -0.152510
# Valencia_wind_speed     -0.012830        -0.024767          -0.142791
# Seville_humidity        -0.703010        -0.675070          -0.167290
# Madrid_humidity         -0.795066        -0.757692          -0.150536
# Bilbao_clouds_all       -0.059928        -0.060271          -0.127293
# Bilbao_wind_speed        0.019764         0.006009          -0.081602
# Seville_clouds_all      -0.222425        -0.213539          -0.091804
# Bilbao_wind_deg          0.063938         0.062808          -0.120800
# Barcelona_wind_speed     0.072738         0.063878          -0.103633
# Barcelona_wind_deg      -0.221852        -0.219746          -0.116133
# Madrid_clouds_all       -0.279496        -0.268680          -0.081623
# Seville_wind_speed       0.110594         0.090169          -0.048433
# Barcelona_rain_1h        0.057780         0.054256          -0.056633
# Seville_rain_1h         -0.123858        -0.113803          -0.031572
# Bilbao_snow_3h          -0.070237        -0.064842          -0.031721
# Barcelona_pressure      -0.015287        -0.015244          -0.034385
# Seville_rain_3h         -0.036963        -0.030311          -0.032945
# Madrid_rain_1h          -0.105603        -0.101818          -0.027159
# Barcelona_rain_3h       -0.032702        -0.023495          -0.024720
# Valencia_snow_3h        -0.020527        -0.018879          -0.021633
# Madrid_weather_id        0.143699         0.137198           0.030868
# Barcelona_weather_id     0.042035         0.040664           0.063868
# Bilbao_pressure         -0.091534        -0.094658           0.039052
# Seville_weather_id       0.189039         0.180755           0.061104
# Valencia_pressure        0.115214         0.078286           0.086022
# Seville_temp_max         0.757081         0.705108           0.109834
# Madrid_pressure          0.049601         0.014615           0.092638
# Valencia_temp_max        0.915525         0.875728           0.144270
# Valencia_temp            0.917144         0.881040           0.173225
# Bilbao_weather_id        0.161759         0.146548           0.145875
# Seville_temp             0.912556         0.873634           0.159343
# Valencia_humidity       -0.241111        -0.223341           0.043140
# Valencia_temp_min        0.899039         0.868788           0.201863
# Barcelona_temp_max       0.904874         0.866011           0.164734
# Madrid_temp_max          0.990703         0.950082           0.182548
# Barcelona_temp           0.908504         0.880456           0.182673
# Bilbao_temp_min          0.880266         0.854735           0.172920
# Bilbao_temp              0.877367         0.846663           0.176411
# Barcelona_temp_min       0.867627         0.854083           0.195984
# Bilbao_temp_max          0.844112         0.809808           0.180934
# Seville_temp_min         0.937541         0.911220           0.174718
# Madrid_temp              1.000000         0.978677           0.186036
# Madrid_temp_min          0.978677         1.000000           0.174744
# load_shortfall_3h        0.186036         0.174744           1.000000
#
# [45 rows x 45 columns]

# %% [markdown]
# The correlation table above shows the correlation coefficients between variables. Each cell in the table shows the correlation between two variables.

# %% [markdown]
# # IV.  Multivariate Analysis: Graphical

# %% [markdown]
# # evaluate correlation

# %% [markdown]
# ### a. Correlation Heatmap

# %%
plt.figure(figsize=(40,30))
heatmap = sns.heatmap(final_data.corr(),cbar=True,annot=True,cmap='Reds')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':9}, pad=12);

# %% [markdown]
# We can see from the correlations that there are multiple correlation between the variables in the datasets.
# - `Seville_humidity` and `Madrid_humidity` are positive correlated, just as `Madrid_temp` and `Madrid_temp_min`, and so on

# %% [markdown]
# ### Scatter Plot

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='Seville_humidity',y='Madrid_humidity',hue='load_shortfall_3h', data=final_data)
# Out:
# <AxesSubplot:xlabel='Seville_humidity', ylabel='Madrid_humidity'>

# %% [markdown]
# From the scatter plot above, looking at the relationships between `Madrid_humidity` and `Seville_humidity`, we can see how much effect the relationship of both variables have on the `load_shortfall_3h`

# %% [markdown]
# <a id="four"></a>
# ## 4. Data Engineering
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Data engineering ⚡ |
# | :--------------------------- |
# | In this section you are required to: clean the dataset, and possibly create new features - as identified in the EDA phase. |
#
# ---

# %%
# remove missing values/ features

#Step 1
#lets tackle nulls in the dataset
final_data['Valencia_pressure']=final_data['Valencia_pressure'].fillna(final_data['Valencia_pressure'].mode()[0])

# %%
final_data['Valencia_wind_deg']
# Out:
# 0        level_5
# 1       level_10
# 2        level_9
# 3        level_8
# 4        level_7
#           ...
# 2915     level_9
# 2916     level_8
# 2917     level_6
# 2918     level_6
# 2919    level_10
# Name: Valencia_wind_deg, Length: 11683, dtype: object

# %%
# engineer existing features
final_data['Valencia_wind_deg'] = final_data['Valencia_wind_deg'].str.extract('(\d+)')
final_data['Valencia_wind_deg'] = pd.to_numeric(final_data['Valencia_wind_deg'])

# %%
final_data['Valencia_wind_deg']
# Out:
# 0        5
# 1       10
# 2        9
# 3        8
# 4        7
#         ..
# 2915     9
# 2916     8
# 2917     6
# 2918     6
# 2919    10
# Name: Valencia_wind_deg, Length: 11683, dtype: int64

# %%
final_data['Seville_pressure']=final_data['Seville_pressure'].str.extract('(\d+)')
final_data['Seville_pressure']=pd.to_numeric(final_data['Seville_pressure'])

# %%
final_data['Seville_pressure']
# Out:
# 0       25
# 1       25
# 2       25
# 3       25
# 4       25
#         ..
# 2915    24
# 2916    24
# 2917    23
# 2918    23
# 2919    23
# Name: Seville_pressure, Length: 11683, dtype: int64

# %% [markdown]
# <a id="five"></a>
# ## 5. Modelling
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Modelling ⚡ |
# | :--------------------------- |
# | In this section, you are required to create one or more regression models that are able to accurately predict the thee hour load shortfall. |
#
# ---

# %%
from sklearn.metrics import mean_squared_error
from sklearn import *
from sklearn.linear_model import *

from tqdm import tqdm
import math
import random

from scipy import stats
from scipy.stats import norm, skew
from scipy.stats import pearsonr
import seaborn as sns

# %%
import time

##We now change the datetime
final_data['time']=pd.to_datetime(final_data['time'])

#We now split the time column into year, month and hour
#final_data['Year']= final_data['time'].dt.year
final_data['Month']=final_data['time'].dt.month
final_data['Hour']=final_data['time'].dt.hour

#Now, let us drop the time column
final_data=final_data.drop(['time'], axis=1)

# %% [markdown]
# We wish to break down months into 4 seasons i.e `Winter(June-Aug)` as 1, and `Spring(Sep-Nov)` as 2,
# `Summer(Dec-mar)` as 3,and `Autumn(Apr-May)` as 4

# %%
def Season(monthID):
    if monthID>=6 and monthID<=8:
        return 1
    elif monthID>=9 and monthID<=11:
        return 2
    elif monthID==12 or monthID<=2:
        return 3
    else:
        return 4

# %% [markdown]
# We wish to break down the day into five i.e `Dusk (1-5)` as 1, `Morning (6-12)` as 2, `Afternoon (13-15)` as 3, `Evening (16-19)` as 4, `Night(20-23.59)` as 5

# %%
def Time_of_day(HourID):
    if HourID<=5:
        return 1
    elif HourID>=6 and HourID<=12:
        return 2
    elif HourID>=13 and HourID<=15:
        return 3
    elif HourID>=16 and HourID<=19:
        return 4
    else:
        return 5

# %%
#Use the functions created in the above cell
final_data['Season']=final_data['Month'].apply(lambda x:Season(x))
final_data['Time_of_day']=final_data['Hour'].apply(lambda x:Time_of_day(x))

#Drop the month and Hour data
final_data=final_data.drop(['Month','Hour'], axis=1)

# %%
final_data.head()
# Out:
#    Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  Valencia_wind_speed  \
# 0           0.666667                  5             0.0             0.666667
# 1           0.333333                 10             0.0             1.666667
# 2           1.000000                  9             0.0             1.000000
# 3           1.000000                  8             0.0             1.000000
# 4           1.000000                  7             0.0             1.000000
#
#    Seville_humidity  Madrid_humidity  Bilbao_clouds_all  Bilbao_wind_speed  \
# 0         74.333333        64.000000                0.0           1.000000
# 1         78.333333        64.666667                0.0           1.000000
# 2         71.333333        64.333333                0.0           1.000000
# 3         65.333333        56.333333                0.0           1.000000
# 4         59.000000        57.000000                2.0           0.333333
#
#    Seville_clouds_all  Bilbao_wind_deg  ...  Bilbao_temp_min  Bilbao_temp  \
# 0                 0.0       223.333333  ...       269.338615   269.338615
# 1                 0.0       221.000000  ...       270.376000   270.376000
# 2                 0.0       214.333333  ...       275.027229   275.027229
# 3                 0.0       199.666667  ...       281.135063   281.135063
# 4                 0.0       185.000000  ...       282.252063   282.252063
#
#    Barcelona_temp_min  Bilbao_temp_max  Seville_temp_min  Madrid_temp  \
# 0          281.013000       269.338615        274.254667   265.938000
# 1          280.561667       270.376000        274.945000   266.386667
# 2          281.583667       275.027229        278.792000   272.708667
# 3          283.434104       281.135063        285.394000   281.895219
# 4          284.213167       282.252063        285.513719   280.678437
#
#    Madrid_temp_min  load_shortfall_3h  Season  Time_of_day
# 0       265.938000        6715.666667       3            1
# 1       266.386667        4171.666667       3            2
# 2       272.708667        4274.666667       3            2
# 3       281.895219        5075.666667       3            2
# 4       280.678437        6620.666667       3            3
#
# [5 rows x 49 columns]

# %% [markdown]
# It seems as if the features are many. We wish to remove the redundant features.
# In this case, we will check those with decent correlation with the 'load_shortfall_3h'
# as well as those with significance (using p-value)

# %%
final_corr=final_data[:len(train)]
# Calculate correlations between predictor variables and the response variable
corrs = final_corr.corr()['load_shortfall_3h'].sort_values(ascending=False)


# Build a dictionary of correlation coefficients and p-values
dict_cp = {}

column_titles = [col for col in corrs.index if col!= 'load_shortfall_3h']
for col in column_titles:
    p_val = round(pearsonr(final_corr[col], final_corr['load_shortfall_3h'])[1],6)
    dict_cp[col] = {'Correlation_Coefficient':corrs[col],
                    'P_Value':p_val}

df_cp = pd.DataFrame(dict_cp).T
df_cp_sorted = df_cp.sort_values('P_Value')
df_cp_sorted[df_cp_sorted['P_Value']<0.1]
# Out:
#                       Correlation_Coefficient   P_Value
# Valencia_temp_min                    0.201863  0.000000
# Seville_weather_id                   0.061104  0.000000
# Valencia_wind_deg                   -0.188674  0.000000
# Barcelona_rain_1h                   -0.056633  0.000000
# Bilbao_wind_speed                   -0.081602  0.000000
# Madrid_clouds_all                   -0.081623  0.000000
# Seville_clouds_all                  -0.091804  0.000000
# Barcelona_wind_speed                -0.103633  0.000000
# Barcelona_wind_deg                  -0.116133  0.000000
# Bilbao_wind_deg                     -0.120800  0.000000
# Bilbao_clouds_all                   -0.127293  0.000000
# Valencia_wind_speed                 -0.142791  0.000000
# Madrid_humidity                     -0.150536  0.000000
# Madrid_wind_speed                   -0.150981  0.000000
# Bilbao_rain_1h                      -0.152510  0.000000
# Seville_humidity                    -0.167290  0.000000
# Barcelona_weather_id                 0.063868  0.000000
# Valencia_pressure                    0.090405  0.000000
# Season                              -0.234862  0.000000
# Seville_temp_max                     0.109834  0.000000
# Barcelona_temp_min                   0.195984  0.000000
# Madrid_temp                          0.186036  0.000000
# Barcelona_temp                       0.182673  0.000000
# Madrid_temp_max                      0.182548  0.000000
# Bilbao_temp_max                      0.180934  0.000000
# Bilbao_temp                          0.176411  0.000000
# Madrid_temp_min                      0.174744  0.000000
# Seville_temp_min                     0.174718  0.000000
# Valencia_temp                        0.173225  0.000000
# Bilbao_temp_min                      0.172920  0.000000
# Barcelona_temp_max                   0.164734  0.000000
# Seville_temp                         0.159343  0.000000
# Madrid_pressure                      0.092638  0.000000
# Bilbao_weather_id                    0.145875  0.000000
# Valencia_temp_max                    0.144270  0.000000
# Time_of_day                          0.118911  0.000000
# Seville_wind_speed                  -0.048433  0.000006
# Valencia_humidity                    0.043140  0.000054
# Bilbao_pressure                      0.039052  0.000256
# Barcelona_pressure                  -0.034385  0.001285
# Seville_rain_3h                     -0.032945  0.002040
# Bilbao_snow_3h                      -0.031721  0.002981
# Seville_rain_1h                     -0.031572  0.003118
# Madrid_weather_id                    0.030868  0.003854
# Seville_pressure                    -0.030434  0.004383
# Madrid_rain_1h                      -0.027159  0.011008
# Barcelona_rain_3h                   -0.024720  0.020665
# Valencia_snow_3h                    -0.021633  0.042863

# %% [markdown]
# It seems all the features are significant. They all have p-values below 0.05 i.e 5% significance. Now let us check for
# collinearity.

# %%
# We are looking for rows and columns where correlation coefficients > 0.9 or <-0.9
corr = final_corr.drop('load_shortfall_3h', axis = 1).corr()
# Find rows and columnd where correlation coefficients > 0.9 or <-0.9
corr[np.abs(corr) > 0.9]
# Out:
#                       Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  \
# Madrid_wind_speed                   1.0                NaN             NaN
# Valencia_wind_deg                   NaN                1.0             NaN
# Bilbao_rain_1h                      NaN                NaN             1.0
# Valencia_wind_speed                 NaN                NaN             NaN
# Seville_humidity                    NaN                NaN             NaN
# Madrid_humidity                     NaN                NaN             NaN
# Bilbao_clouds_all                   NaN                NaN             NaN
# Bilbao_wind_speed                   NaN                NaN             NaN
# Seville_clouds_all                  NaN                NaN             NaN
# Bilbao_wind_deg                     NaN                NaN             NaN
# Barcelona_wind_speed                NaN                NaN             NaN
# Barcelona_wind_deg                  NaN                NaN             NaN
# Madrid_clouds_all                   NaN                NaN             NaN
# Seville_wind_speed                  NaN                NaN             NaN
# Barcelona_rain_1h                   NaN                NaN             NaN
# Seville_pressure                    NaN                NaN             NaN
# Seville_rain_1h                     NaN                NaN             NaN
# Bilbao_snow_3h                      NaN                NaN             NaN
# Barcelona_pressure                  NaN                NaN             NaN
# Seville_rain_3h                     NaN                NaN             NaN
# Madrid_rain_1h                      NaN                NaN             NaN
# Barcelona_rain_3h                   NaN                NaN             NaN
# Valencia_snow_3h                    NaN                NaN             NaN
# Madrid_weather_id                   NaN                NaN             NaN
# Barcelona_weather_id                NaN                NaN             NaN
# Bilbao_pressure                     NaN                NaN             NaN
# Seville_weather_id                  NaN                NaN             NaN
# Valencia_pressure                   NaN                NaN             NaN
# Seville_temp_max                    NaN                NaN             NaN
# Madrid_pressure                     NaN                NaN             NaN
# Valencia_temp_max                   NaN                NaN             NaN
# Valencia_temp                       NaN                NaN             NaN
# Bilbao_weather_id                   NaN                NaN             NaN
# Seville_temp                        NaN                NaN             NaN
# Valencia_humidity                   NaN                NaN             NaN
# Valencia_temp_min                   NaN                NaN             NaN
# Barcelona_temp_max                  NaN                NaN             NaN
# Madrid_temp_max                     NaN                NaN             NaN
# Barcelona_temp                      NaN                NaN             NaN
# Bilbao_temp_min                     NaN                NaN             NaN
# Bilbao_temp                         NaN                NaN             NaN
# Barcelona_temp_min                  NaN                NaN             NaN
# Bilbao_temp_max                     NaN                NaN             NaN
# Seville_temp_min                    NaN                NaN             NaN
# Madrid_temp                         NaN                NaN             NaN
# Madrid_temp_min                     NaN                NaN             NaN
# Season                              NaN                NaN             NaN
# Time_of_day                         NaN                NaN             NaN
#
#                       Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# Madrid_wind_speed                     NaN               NaN              NaN
# Valencia_wind_deg                     NaN               NaN              NaN
# Bilbao_rain_1h                        NaN               NaN              NaN
# Valencia_wind_speed                   1.0               NaN              NaN
# Seville_humidity                      NaN               1.0              NaN
# Madrid_humidity                       NaN               NaN              1.0
# Bilbao_clouds_all                     NaN               NaN              NaN
# Bilbao_wind_speed                     NaN               NaN              NaN
# Seville_clouds_all                    NaN               NaN              NaN
# Bilbao_wind_deg                       NaN               NaN              NaN
# Barcelona_wind_speed                  NaN               NaN              NaN
# Barcelona_wind_deg                    NaN               NaN              NaN
# Madrid_clouds_all                     NaN               NaN              NaN
# Seville_wind_speed                    NaN               NaN              NaN
# Barcelona_rain_1h                     NaN               NaN              NaN
# Seville_pressure                      NaN               NaN              NaN
# Seville_rain_1h                       NaN               NaN              NaN
# Bilbao_snow_3h                        NaN               NaN              NaN
# Barcelona_pressure                    NaN               NaN              NaN
# Seville_rain_3h                       NaN               NaN              NaN
# Madrid_rain_1h                        NaN               NaN              NaN
# Barcelona_rain_3h                     NaN               NaN              NaN
# Valencia_snow_3h                      NaN               NaN              NaN
# Madrid_weather_id                     NaN               NaN              NaN
# Barcelona_weather_id                  NaN               NaN              NaN
# Bilbao_pressure                       NaN               NaN              NaN
# Seville_weather_id                    NaN               NaN              NaN
# Valencia_pressure                     NaN               NaN              NaN
# Seville_temp_max                      NaN               NaN              NaN
# Madrid_pressure                       NaN               NaN              NaN
# Valencia_temp_max                     NaN               NaN              NaN
# Valencia_temp                         NaN               NaN              NaN
# Bilbao_weather_id                     NaN               NaN              NaN
# Seville_temp                          NaN               NaN              NaN
# Valencia_humidity                     NaN               NaN              NaN
# Valencia_temp_min                     NaN               NaN              NaN
# Barcelona_temp_max                    NaN               NaN              NaN
# Madrid_temp_max                       NaN               NaN              NaN
# Barcelona_temp                        NaN               NaN              NaN
# Bilbao_temp_min                       NaN               NaN              NaN
# Bilbao_temp                           NaN               NaN              NaN
# Barcelona_temp_min                    NaN               NaN              NaN
# Bilbao_temp_max                       NaN               NaN              NaN
# Seville_temp_min                      NaN               NaN              NaN
# Madrid_temp                           NaN               NaN              NaN
# Madrid_temp_min                       NaN               NaN              NaN
# Season                                NaN               NaN              NaN
# Time_of_day                           NaN               NaN              NaN
#
#                       Bilbao_clouds_all  Bilbao_wind_speed  \
# Madrid_wind_speed                   NaN                NaN
# Valencia_wind_deg                   NaN                NaN
# Bilbao_rain_1h                      NaN                NaN
# Valencia_wind_speed                 NaN                NaN
# Seville_humidity                    NaN                NaN
# Madrid_humidity                     NaN                NaN
# Bilbao_clouds_all                   1.0                NaN
# Bilbao_wind_speed                   NaN                1.0
# Seville_clouds_all                  NaN                NaN
# Bilbao_wind_deg                     NaN                NaN
# Barcelona_wind_speed                NaN                NaN
# Barcelona_wind_deg                  NaN                NaN
# Madrid_clouds_all                   NaN                NaN
# Seville_wind_speed                  NaN                NaN
# Barcelona_rain_1h                   NaN                NaN
# Seville_pressure                    NaN                NaN
# Seville_rain_1h                     NaN                NaN
# Bilbao_snow_3h                      NaN                NaN
# Barcelona_pressure                  NaN                NaN
# Seville_rain_3h                     NaN                NaN
# Madrid_rain_1h                      NaN                NaN
# Barcelona_rain_3h                   NaN                NaN
# Valencia_snow_3h                    NaN                NaN
# Madrid_weather_id                   NaN                NaN
# Barcelona_weather_id                NaN                NaN
# Bilbao_pressure                     NaN                NaN
# Seville_weather_id                  NaN                NaN
# Valencia_pressure                   NaN                NaN
# Seville_temp_max                    NaN                NaN
# Madrid_pressure                     NaN                NaN
# Valencia_temp_max                   NaN                NaN
# Valencia_temp                       NaN                NaN
# Bilbao_weather_id                   NaN                NaN
# Seville_temp                        NaN                NaN
# Valencia_humidity                   NaN                NaN
# Valencia_temp_min                   NaN                NaN
# Barcelona_temp_max                  NaN                NaN
# Madrid_temp_max                     NaN                NaN
# Barcelona_temp                      NaN                NaN
# Bilbao_temp_min                     NaN                NaN
# Bilbao_temp                         NaN                NaN
# Barcelona_temp_min                  NaN                NaN
# Bilbao_temp_max                     NaN                NaN
# Seville_temp_min                    NaN                NaN
# Madrid_temp                         NaN                NaN
# Madrid_temp_min                     NaN                NaN
# Season                              NaN                NaN
# Time_of_day                         NaN                NaN
#
#                       Seville_clouds_all  Bilbao_wind_deg  ...  \
# Madrid_wind_speed                    NaN              NaN  ...
# Valencia_wind_deg                    NaN              NaN  ...
# Bilbao_rain_1h                       NaN              NaN  ...
# Valencia_wind_speed                  NaN              NaN  ...
# Seville_humidity                     NaN              NaN  ...
# Madrid_humidity                      NaN              NaN  ...
# Bilbao_clouds_all                    NaN              NaN  ...
# Bilbao_wind_speed                    NaN              NaN  ...
# Seville_clouds_all                   1.0              NaN  ...
# Bilbao_wind_deg                      NaN              1.0  ...
# Barcelona_wind_speed                 NaN              NaN  ...
# Barcelona_wind_deg                   NaN              NaN  ...
# Madrid_clouds_all                    NaN              NaN  ...
# Seville_wind_speed                   NaN              NaN  ...
# Barcelona_rain_1h                    NaN              NaN  ...
# Seville_pressure                     NaN              NaN  ...
# Seville_rain_1h                      NaN              NaN  ...
# Bilbao_snow_3h                       NaN              NaN  ...
# Barcelona_pressure                   NaN              NaN  ...
# Seville_rain_3h                      NaN              NaN  ...
# Madrid_rain_1h                       NaN              NaN  ...
# Barcelona_rain_3h                    NaN              NaN  ...
# Valencia_snow_3h                     NaN              NaN  ...
# Madrid_weather_id                    NaN              NaN  ...
# Barcelona_weather_id                 NaN              NaN  ...
# Bilbao_pressure                      NaN              NaN  ...
# Seville_weather_id                   NaN              NaN  ...
# Valencia_pressure                    NaN              NaN  ...
# Seville_temp_max                     NaN              NaN  ...
# Madrid_pressure                      NaN              NaN  ...
# Valencia_temp_max                    NaN              NaN  ...
# Valencia_temp                        NaN              NaN  ...
# Bilbao_weather_id                    NaN              NaN  ...
# Seville_temp                         NaN              NaN  ...
# Valencia_humidity                    NaN              NaN  ...
# Valencia_temp_min                    NaN              NaN  ...
# Barcelona_temp_max                   NaN              NaN  ...
# Madrid_temp_max                      NaN              NaN  ...
# Barcelona_temp                       NaN              NaN  ...
# Bilbao_temp_min                      NaN              NaN  ...
# Bilbao_temp                          NaN              NaN  ...
# Barcelona_temp_min                   NaN              NaN  ...
# Bilbao_temp_max                      NaN              NaN  ...
# Seville_temp_min                     NaN              NaN  ...
# Madrid_temp                          NaN              NaN  ...
# Madrid_temp_min                      NaN              NaN  ...
# Season                               NaN              NaN  ...
# Time_of_day                          NaN              NaN  ...
#
#                       Barcelona_temp  Bilbao_temp_min  Bilbao_temp  \
# Madrid_wind_speed                NaN              NaN          NaN
# Valencia_wind_deg                NaN              NaN          NaN
# Bilbao_rain_1h                   NaN              NaN          NaN
# Valencia_wind_speed              NaN              NaN          NaN
# Seville_humidity                 NaN              NaN          NaN
# Madrid_humidity                  NaN              NaN          NaN
# Bilbao_clouds_all                NaN              NaN          NaN
# Bilbao_wind_speed                NaN              NaN          NaN
# Seville_clouds_all               NaN              NaN          NaN
# Bilbao_wind_deg                  NaN              NaN          NaN
# Barcelona_wind_speed             NaN              NaN          NaN
# Barcelona_wind_deg               NaN              NaN          NaN
# Madrid_clouds_all                NaN              NaN          NaN
# Seville_wind_speed               NaN              NaN          NaN
# Barcelona_rain_1h                NaN              NaN          NaN
# Seville_pressure                 NaN              NaN          NaN
# Seville_rain_1h                  NaN              NaN          NaN
# Bilbao_snow_3h                   NaN              NaN          NaN
# Barcelona_pressure               NaN              NaN          NaN
# Seville_rain_3h                  NaN              NaN          NaN
# Madrid_rain_1h                   NaN              NaN          NaN
# Barcelona_rain_3h                NaN              NaN          NaN
# Valencia_snow_3h                 NaN              NaN          NaN
# Madrid_weather_id                NaN              NaN          NaN
# Barcelona_weather_id             NaN              NaN          NaN
# Bilbao_pressure                  NaN              NaN          NaN
# Seville_weather_id               NaN              NaN          NaN
# Valencia_pressure                NaN              NaN          NaN
# Seville_temp_max                 NaN              NaN          NaN
# Madrid_pressure                  NaN              NaN          NaN
# Valencia_temp_max           0.912094              NaN          NaN
# Valencia_temp               0.914601              NaN          NaN
# Bilbao_weather_id                NaN              NaN          NaN
# Seville_temp                     NaN              NaN          NaN
# Valencia_humidity                NaN              NaN          NaN
# Valencia_temp_min                NaN              NaN          NaN
# Barcelona_temp_max          0.974480              NaN          NaN
# Madrid_temp_max             0.900428              NaN          NaN
# Barcelona_temp              1.000000              NaN          NaN
# Bilbao_temp_min                  NaN         1.000000     0.982936
# Bilbao_temp                      NaN         0.982936     1.000000
# Barcelona_temp_min          0.964089              NaN          NaN
# Bilbao_temp_max                  NaN         0.932219     0.981624
# Seville_temp_min                 NaN              NaN          NaN
# Madrid_temp                 0.903143              NaN          NaN
# Madrid_temp_min                  NaN              NaN          NaN
# Season                           NaN              NaN          NaN
# Time_of_day                      NaN              NaN          NaN
#
#                       Barcelona_temp_min  Bilbao_temp_max  Seville_temp_min  \
# Madrid_wind_speed                    NaN              NaN               NaN
# Valencia_wind_deg                    NaN              NaN               NaN
# Bilbao_rain_1h                       NaN              NaN               NaN
# Valencia_wind_speed                  NaN              NaN               NaN
# Seville_humidity                     NaN              NaN               NaN
# Madrid_humidity                      NaN              NaN               NaN
# Bilbao_clouds_all                    NaN              NaN               NaN
# Bilbao_wind_speed                    NaN              NaN               NaN
# Seville_clouds_all                   NaN              NaN               NaN
# Bilbao_wind_deg                      NaN              NaN               NaN
# Barcelona_wind_speed                 NaN              NaN               NaN
# Barcelona_wind_deg                   NaN              NaN               NaN
# Madrid_clouds_all                    NaN              NaN               NaN
# Seville_wind_speed                   NaN              NaN               NaN
# Barcelona_rain_1h                    NaN              NaN               NaN
# Seville_pressure                     NaN              NaN               NaN
# Seville_rain_1h                      NaN              NaN               NaN
# Bilbao_snow_3h                       NaN              NaN               NaN
# Barcelona_pressure                   NaN              NaN               NaN
# Seville_rain_3h                      NaN              NaN               NaN
# Madrid_rain_1h                       NaN              NaN               NaN
# Barcelona_rain_3h                    NaN              NaN               NaN
# Valencia_snow_3h                     NaN              NaN               NaN
# Madrid_weather_id                    NaN              NaN               NaN
# Barcelona_weather_id                 NaN              NaN               NaN
# Bilbao_pressure                      NaN              NaN               NaN
# Seville_weather_id                   NaN              NaN               NaN
# Valencia_pressure                    NaN              NaN               NaN
# Seville_temp_max                     NaN              NaN               NaN
# Madrid_pressure                      NaN              NaN               NaN
# Valencia_temp_max                    NaN              NaN               NaN
# Valencia_temp                        NaN              NaN               NaN
# Bilbao_weather_id                    NaN              NaN               NaN
# Seville_temp                         NaN              NaN          0.955160
# Valencia_humidity                    NaN              NaN               NaN
# Valencia_temp_min                    NaN              NaN               NaN
# Barcelona_temp_max                   NaN              NaN               NaN
# Madrid_temp_max                      NaN              NaN          0.923481
# Barcelona_temp                  0.964089              NaN               NaN
# Bilbao_temp_min                      NaN         0.932219               NaN
# Bilbao_temp                          NaN         0.981624               NaN
# Barcelona_temp_min              1.000000              NaN               NaN
# Bilbao_temp_max                      NaN         1.000000               NaN
# Seville_temp_min                     NaN              NaN          1.000000
# Madrid_temp                          NaN              NaN          0.939079
# Madrid_temp_min                      NaN              NaN          0.907758
# Season                               NaN              NaN               NaN
# Time_of_day                          NaN              NaN               NaN
#
#                       Madrid_temp  Madrid_temp_min  Season  Time_of_day
# Madrid_wind_speed             NaN              NaN     NaN          NaN
# Valencia_wind_deg             NaN              NaN     NaN          NaN
# Bilbao_rain_1h                NaN              NaN     NaN          NaN
# Valencia_wind_speed           NaN              NaN     NaN          NaN
# Seville_humidity              NaN              NaN     NaN          NaN
# Madrid_humidity               NaN              NaN     NaN          NaN
# Bilbao_clouds_all             NaN              NaN     NaN          NaN
# Bilbao_wind_speed             NaN              NaN     NaN          NaN
# Seville_clouds_all            NaN              NaN     NaN          NaN
# Bilbao_wind_deg               NaN              NaN     NaN          NaN
# Barcelona_wind_speed          NaN              NaN     NaN          NaN
# Barcelona_wind_deg            NaN              NaN     NaN          NaN
# Madrid_clouds_all             NaN              NaN     NaN          NaN
# Seville_wind_speed            NaN              NaN     NaN          NaN
# Barcelona_rain_1h             NaN              NaN     NaN          NaN
# Seville_pressure              NaN              NaN     NaN          NaN
# Seville_rain_1h               NaN              NaN     NaN          NaN
# Bilbao_snow_3h                NaN              NaN     NaN          NaN
# Barcelona_pressure            NaN              NaN     NaN          NaN
# Seville_rain_3h               NaN              NaN     NaN          NaN
# Madrid_rain_1h                NaN              NaN     NaN          NaN
# Barcelona_rain_3h             NaN              NaN     NaN          NaN
# Valencia_snow_3h              NaN              NaN     NaN          NaN
# Madrid_weather_id             NaN              NaN     NaN          NaN
# Barcelona_weather_id          NaN              NaN     NaN          NaN
# Bilbao_pressure               NaN              NaN     NaN          NaN
# Seville_weather_id            NaN              NaN     NaN          NaN
# Valencia_pressure             NaN              NaN     NaN          NaN
# Seville_temp_max              NaN              NaN     NaN          NaN
# Madrid_pressure               NaN              NaN     NaN          NaN
# Valencia_temp_max        0.911331              NaN     NaN          NaN
# Valencia_temp            0.915753              NaN     NaN          NaN
# Bilbao_weather_id             NaN              NaN     NaN          NaN
# Seville_temp             0.917075              NaN     NaN          NaN
# Valencia_humidity             NaN              NaN     NaN          NaN
# Valencia_temp_min             NaN              NaN     NaN          NaN
# Barcelona_temp_max            NaN              NaN     NaN          NaN
# Madrid_temp_max          0.988871         0.939147     NaN          NaN
# Barcelona_temp           0.903143              NaN     NaN          NaN
# Bilbao_temp_min               NaN              NaN     NaN          NaN
# Bilbao_temp                   NaN              NaN     NaN          NaN
# Barcelona_temp_min            NaN              NaN     NaN          NaN
# Bilbao_temp_max               NaN              NaN     NaN          NaN
# Seville_temp_min         0.939079         0.907758     NaN          NaN
# Madrid_temp              1.000000         0.973641     NaN          NaN
# Madrid_temp_min          0.973641         1.000000     NaN          NaN
# Season                        NaN              NaN     1.0          NaN
# Time_of_day                   NaN              NaN     NaN          1.0
#
# [48 rows x 48 columns]

# %% [markdown]
# From the cross-correlation, it is observed that temp,temp_min and temp_max for the all the cities are highly correlated.
# This could lead to multi-collinearity.
#
# The significance check earlier done shows that apart from madrid, temp_min is the most significant feature.
# For this reason, we drop temp and temp_max for all the cities

# %%
final_data=final_data.drop(['Barcelona_temp', 'Barcelona_temp_max','Madrid_temp', 'Madrid_temp_max','Seville_temp', 'Seville_temp_max','Bilbao_temp', 'Bilbao_temp_max','Valencia_temp', 'Valencia_temp_max'], axis=1)

# %%
y = final_data[:len(train)][['load_shortfall_3h']]
x = final_data[:len(train)].drop('load_shortfall_3h', axis = 1)

#x_train = final_data[:len(final_data)].drop('load_shortfall_3h', axis = 1)
#x_test = final_data[len(final_data):].drop('load_shortfall_3h', axis = 1)

# %%
x.head()
# Out:
#    Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  Valencia_wind_speed  \
# 0           0.666667                  5             0.0             0.666667
# 1           0.333333                 10             0.0             1.666667
# 2           1.000000                  9             0.0             1.000000
# 3           1.000000                  8             0.0             1.000000
# 4           1.000000                  7             0.0             1.000000
#
#    Seville_humidity  Madrid_humidity  Bilbao_clouds_all  Bilbao_wind_speed  \
# 0         74.333333        64.000000                0.0           1.000000
# 1         78.333333        64.666667                0.0           1.000000
# 2         71.333333        64.333333                0.0           1.000000
# 3         65.333333        56.333333                0.0           1.000000
# 4         59.000000        57.000000                2.0           0.333333
#
#    Seville_clouds_all  Bilbao_wind_deg  ...  Madrid_pressure  \
# 0                 0.0       223.333333  ...       971.333333
# 1                 0.0       221.000000  ...       972.666667
# 2                 0.0       214.333333  ...       974.000000
# 3                 0.0       199.666667  ...       994.666667
# 4                 0.0       185.000000  ...      1035.333333
#
#    Bilbao_weather_id  Valencia_humidity  Valencia_temp_min  Bilbao_temp_min  \
# 0              800.0          75.666667         269.888000       269.338615
# 1              800.0          71.000000         271.728333       270.376000
# 2              800.0          65.666667         278.008667       275.027229
# 3              800.0          54.000000         284.899552       281.135063
# 4              800.0          58.333333         283.015115       282.252063
#
#    Barcelona_temp_min  Seville_temp_min  Madrid_temp_min  Season  Time_of_day
# 0          281.013000        274.254667       265.938000       3            1
# 1          280.561667        274.945000       266.386667       3            2
# 2          281.583667        278.792000       272.708667       3            2
# 3          283.434104        285.394000       281.895219       3            2
# 4          284.213167        285.513719       280.678437       3            3
#
# [5 rows x 38 columns]

# %%
y.head()
# Out:
#    load_shortfall_3h
# 0        6715.666667
# 1        4171.666667
# 2        4274.666667
# 3        5075.666667
# 4        6620.666667

# %%
#Select model
lr = LinearRegression()

# %% [markdown]
# # split data

# %%
#Split dataset into train and test
from sklearn.model_selection import train_test_split as tts

x_train, x_test, y_train, y_test = tts(x, y, test_size = 0.2)

# %% [markdown]
# # create one or more ML models

# %% [markdown]
# ### Fit lr model to x_train and y_train...Then predict

# %%
lr.fit(x_train, y_train)

prediction = lr.predict(x_test)

# %% [markdown]
# # evaluate one or more ML models

# %% [markdown]
# ### Evaluate Model (RMSE)

# %%
def rmse(y_test, y_predict):
    return np.sqrt(mean_squared_error(y_test, y_predict))

# %%
rmse(y_test, prediction)
# Out:
# 4834.740933196417

# %% [markdown]
# ## Calculate r_score

# %%
from sklearn.metrics import r2_score
r2_score(y_test,prediction)
# Out:
# 0.13416256103515667

# %%
x_train
# Out:
#       Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  \
# 236            8.000000                  9             3.0
# 3631           2.333333                  4             0.0
# 7245           2.333333                  7             0.0
# 4041           1.000000                  5             0.0
# 6343           4.333333                  8             0.0
# ...                 ...                ...             ...
# 4780           3.333333                  3             0.0
# 7041           3.000000                  4             0.0
# 8253           1.000000                  1             0.0
# 4012           1.333333                  7             0.0
# 3523           0.666667                  7             0.6
#
#       Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 236             17.666667         83.000000        93.000000
# 3631             2.333333         59.333333        49.000000
# 7245             1.333333         37.000000        33.666667
# 4041             5.000000         29.333333        34.666667
# 6343             5.333333         93.000000        66.666667
# ...                   ...               ...              ...
# 4780             4.666667         72.333333        53.000000
# 7041             3.333333         27.333333        31.333333
# 8253             1.000000         85.333333        71.000000
# 4012             0.666667         86.000000        59.333333
# 3523             1.000000         82.333333        66.666667
#
#       Bilbao_clouds_all  Bilbao_wind_speed  Seville_clouds_all  \
# 236           92.000000           5.333333           92.000000
# 3631          66.333333           2.666667            6.666667
# 7245          55.000000           0.666667            0.000000
# 4041           0.000000           2.666667            0.000000
# 6343          63.333333           4.000000           80.000000
# ...                 ...                ...                 ...
# 4780          30.666667           0.666667            0.000000
# 7041          75.000000           1.333333            0.000000
# 8253          56.666667           1.000000            0.000000
# 4012          25.000000           0.000000            0.000000
# 3523          62.666667           0.000000            0.000000
#
#       Bilbao_wind_deg  ...  Madrid_pressure  Bilbao_weather_id  \
# 236        280.333333  ...       936.000000         502.000000
# 3631       219.000000  ...      1012.666667         802.666667
# 7245        22.000000  ...      1017.000000         747.333333
# 4041       300.000000  ...      1018.666667         800.000000
# 6343       273.333333  ...      1008.000000         802.666667
# ...               ...  ...              ...                ...
# 4780         0.000000  ...      1021.333333         801.666667
# 7041       313.333333  ...      1015.000000         803.000000
# 8253        93.333333  ...      1023.666667         775.666667
# 4012         0.000000  ...      1020.333333         767.000000
# 3523       296.000000  ...      1017.000000         601.666667
#
#       Valencia_humidity  Valencia_temp_min  Bilbao_temp_min  \
# 236           74.666667         288.838896       281.806177
# 3631          47.000000         292.127833       288.387833
# 7245          79.666667         297.483333       286.150000
# 4041          55.333333         294.350000       292.410000
# 6343          56.333333         284.816667       279.816667
# ...                 ...                ...              ...
# 4780          78.000000         294.816667       283.816667
# 7041          63.333333         296.483333       291.150000
# 8253          83.666667         286.150000       275.150000
# 4012          80.333333         284.173333       279.150000
# 3523          67.000000         281.633667       276.972000
#
#       Barcelona_temp_min  Seville_temp_min  Madrid_temp_min  Season  \
# 236           283.450000        288.558000       284.070500       3
# 3631          287.536167        293.021167       289.756167       4
# 7245          296.483333        299.483333       293.150000       1
# 4041          291.296667        303.816667       298.850000       4
# 6343          285.150000        286.483333       277.483333       4
# ...                  ...               ...              ...     ...
# 4780          292.963333        292.816667       292.050000       1
# 7041          296.483333        301.816667       294.150000       4
# 8253          286.483333        284.483333       280.150000       2
# 4012          283.893333        290.150000       282.780000       4
# 3523          281.316667        286.813333       277.205333       4
#
#       Time_of_day
# 236             5
# 3631            2
# 7245            2
# 4041            4
# 6343            2
# ...           ...
# 4780            1
# 7041            4
# 8253            2
# 4012            1
# 3523            1
#
# [7010 rows x 38 columns]

# %%
# create targets and features dataset

# %%
# import scaler method from sklearn
from sklearn.preprocessing import StandardScaler

# %%
# create scaler object
scaler = StandardScaler()

# %%
# create scaled version of the predictors (there is no need to scale the response)
X_scaled = scaler.fit_transform(x)

# %%
# convert the scaled predictor values into a dataframe
X_standardise = pd.DataFrame(X_scaled,columns=x.columns)
X_standardise.head()
# Out:
#    Madrid_wind_speed  Valencia_wind_deg  Bilbao_rain_1h  Valencia_wind_speed  \
# 0          -0.950708          -0.096053       -0.362123            -0.796169
# 1          -1.130863           1.641580       -0.362123            -0.381412
# 2          -0.770554           1.294054       -0.362123            -0.657917
# 3          -0.770554           0.946527       -0.362123            -0.657917
# 4          -0.770554           0.599000       -0.362123            -0.657917
#
#    Seville_humidity  Madrid_humidity  Bilbao_clouds_all  Bilbao_wind_speed  \
# 0          0.516117         0.270621          -1.335491          -0.501451
# 1          0.692953         0.298017          -1.335491          -0.501451
# 2          0.383491         0.284319          -1.335491          -0.501451
# 3          0.118238        -0.044439          -1.335491          -0.501451
# 4         -0.161751        -0.017043          -1.274045          -0.894581
#
#    Seville_clouds_all  Bilbao_wind_deg  ...  Madrid_pressure  \
# 0           -0.565065         0.630823  ...        -1.756232
# 1           -0.565065         0.607959  ...        -1.696165
# 2           -0.565065         0.542632  ...        -1.636097
# 3           -0.565065         0.398912  ...        -0.705052
# 4           -0.565065         0.255192  ...         1.127003
#
#    Bilbao_weather_id  Valencia_humidity  Valencia_temp_min  Bilbao_temp_min  \
# 0           0.649842           0.540928          -2.892663        -2.338357
# 1           0.649842           0.298645          -2.626219        -2.183645
# 2           0.649842           0.021750          -1.716949        -1.489980
# 3           0.649842          -0.583957          -0.719283        -0.579082
# 4           0.649842          -0.358980          -0.992113        -0.412497
#
#    Barcelona_temp_min  Seville_temp_min  Madrid_temp_min   Season  Time_of_day
# 0           -1.218309         -2.125118        -2.309892  0.44688    -1.133622
# 1           -1.292271         -2.040702        -2.261154  0.44688    -0.377730
# 2           -1.124792         -1.570279        -1.574407  0.44688    -0.377730
# 3           -0.821553         -0.762967        -0.576488  0.44688    -0.377730
# 4           -0.693885         -0.748327        -0.708665  0.44688     0.378162
#
# [5 rows x 38 columns]

# %%
#Split dataset into train and test
from sklearn.model_selection import train_test_split as tts

x_train, x_test, y_train, y_test = tts(X_standardise, y, test_size = 0.2)

# %%
lr.fit(x_train, y_train)

prediction = lr.predict(x_test)

# %%
def rmse(y_test, y_predict):
    return np.sqrt(mean_squared_error(y_test, y_predict))

# %%
rmse(y_test, prediction)
# Out:
# 4753.6084788927365

# %%
from sklearn.metrics import r2_score
r2_score(y_test,prediction)
# Out:
# 0.15129931412759734

# %% [markdown]
# <a id="six"></a>
# ## 6. Model Performance
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Model performance ⚡ |
# | :--------------------------- |
# | In this section you are required to compare the relative performance of the various trained ML models on a holdout dataset and comment on what model is the best and why. |
#
# ---

# %%
# Compare model performance

# %%
# Choose best model and motivate why it is the best choice
#Split dataset into train and test
from sklearn.model_selection import train_test_split as tts

x_train, x_test, y_train, y_test = tts(x, y, test_size = 0.2)

# %% [markdown]
# <a id="seven"></a>
# ## 7. Model Explanations
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Model explanation ⚡ |
# | :--------------------------- |
# | In this section, you are required to discuss how the best performing model works in a simple way so that both technical and non-technical stakeholders can grasp the intuition behind the model's inner workings. |
#
# ---

# %%
# discuss chosen methods logic

# %% [markdown]
# ## This is for the submission process

# %%
x_train = final_data[:len(train)].drop('load_shortfall_3h', axis = 1)
x_test = final_data[len(train):].drop('load_shortfall_3h', axis = 1)

# %%
lr.fit(x_train, y)
prediction = lr.predict(x_test)

# %%
daf = pd.DataFrame(prediction, columns = ['load_shortfall_3h'])
daf.head()
# Out:
#    load_shortfall_3h
# 0        8740.990598
# 1        8079.665469
# 2        8982.195009
# 3        9746.458596
# 4        8756.649520

# %%
output = pd.DataFrame({'time':test['time']})
submission = output.join(daf)
submission.to_csv('submission.csv', index = False)
